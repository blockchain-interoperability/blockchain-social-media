# %%
Path('hi/bye').name
# Out:
# 'bye'

# %%
import numpy as np
np.argsort(pd.to_datetime(['2022-01-03','2022-01-02']))
# Out:
# array([1, 0])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

import pandas as pd
df = pd.DataFrame(gg[:20],columns=['1-Gram','Frequency'])

fig,ax = plt.subplots(figsize=(8,8))

sns.barplot(
    data=df,
    x = 'Frequency',
    y = '1-Gram',
    ax=ax
)
# Out:
# <AxesSubplot:xlabel='Frequency', ylabel='1-Gram'>
