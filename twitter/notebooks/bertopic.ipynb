# %%
from bertopic import BERTopic
import pandas as pd
from pathlib import Path

# %%
model = BERTopic()
whole_text = pd.read_pickle('/data/blockchain-interoperability/blockchain-social-media/twitter-data/snapshots/whole_text.pkl')

# %%
topics, probabilities = model.fit_transform(whole_text.tolist())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 topics, probabilities = model.fit_transform(whole_text.tolist())
#
# File /data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib/python3.10/site-packages/bertopic/_bertopic.py:344, in BERTopic.fit_transform(self, documents, embeddings, y)
#     341 if embeddings is None:
#     342     self.embedding_model = select_backend(self.embedding_model,
#     343                                           language=self.language)
# --> 344     embeddings = self._extract_embeddings(documents.Document,
#     345                                           method="document",
#     346                                           verbose=self.verbose)
#     347     logger.info("Transformed documents to Embeddings")
#     348 else:
#
# ...
