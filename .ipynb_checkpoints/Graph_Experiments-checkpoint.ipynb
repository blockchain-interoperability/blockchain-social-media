# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from crypto_chatter.graph import *

import networkx as nx

data_source = 'twitter'
index_name = 'blockchain-interoperability-attacks'

# %%
graph = CryptoTwitterUserGraph(index_name)
# Out:
# loaded graph edges in 23 seconds
# loaded cached graph data in 163 seconds
# constructed complete user graph in 224 seconds

# %%
G = graph.G

# %%
df = graph.data

# %%
len(df)
# Out:
# 16625047

# %%
len(G.nodes)
# Out:
# 1640251

# %%
len(G.edges)
# Out:
# 2520608

# %%
df.head()
# Out:
#                        created_at  \
# 0  Fri Nov 11 12:03:53 +0000 2022
# 1  Fri Nov 11 12:03:53 +0000 2022
# 2  Fri Nov 11 12:03:53 +0000 2022
# 3  Fri Nov 11 12:03:54 +0000 2022
# 4  Fri Nov 11 12:03:54 +0000 2022
#
#                             extended_tweet.full_text  favorite_count  \
# 0                                                NaN               0
# 1  Never seen such a deal for a punk since 2017! ...               0
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...               0
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...               0
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...               0
#
#                                            full_text  geo geo.coordinates  \
# 0  @0x5ab0 @Uniswap oh, missed fiat part, just sa...  NaN             NaN
# 1  Never seen such a deal for a punk since 2017! ...  NaN             NaN
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...  NaN             NaN
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...  NaN             NaN
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...  NaN             NaN
#
#   geo.type                   id  quote_count        quoted_status.created_at  \
# 0      NaN  1591039006850310148            0                             NaN
# 1      NaN  1591039006770622468            0  Fri Nov 11 11:00:59 +0000 2022
# 2      NaN  1591039006501994503            0                             NaN
# 3      NaN  1591039007357550592            0                             NaN
# 4      NaN  1591039007764668417            0                             NaN
#
#    ... truncated  truncatedquoted_status.truncated  \
# 0  ...     False                               NaN
# 1  ...      True                               NaN
# 2  ...      True                               NaN
# 3  ...      True                               NaN
# 4  ...      True                               NaN
#
#                   user.created_at  user.followers_count  user.friends_count  \
# 0  Mon Jul 11 06:36:43 +0000 2011                  7050                5554
# 1  Wed Nov 09 14:09:46 +0000 2022                     0                   2
# 2  Sun May 01 15:06:34 +0000 2022                   106                   2
# 3  Wed Dec 18 21:46:55 +0000 2013                     0                   0
# 4  Tue Oct 25 03:46:04 +0000 2022                     3                  50
#
#    user.geo_enabled              user.id   user.location  \
# 0              True            333239871  CARBONdale, CO
# 1             False  1590345908172083201     Netherlands
# 2             False  1520781667769614337      blockchain
# 3             False           2252580014            None
# 4             False  1584753080113025025            None
#
#   quoted_status.geo.coordinates  quoted_status.geo.type
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
# [5 rows x 39 columns]

# %%
degrees = dict(G.degree())
degrees = sorted(degrees.items(), key=lambda x: x[1], reverse=True)
degrees = [degree for _, degree in degrees]

# %%
unique_degrees, degree_frequencies = np.unique(degrees, return_counts=True)
plt.bar(unique_degrees, degree_frequencies, color='blue', edgecolor='black')
plt.xscale('log')
plt.yscale('log')
plt.title('Node Degrees Histogram')
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.show()

# %%
all_scc = list(nx.strongly_connected_components(G))
all_scc = sorted(all_scc, key=len, reverse=True)

# %%
scc_sizes = [len(scc) for scc in all_scc]
scc_sizes, scc_frequencies = np.unique(scc_sizes, return_counts=True)


# Plot the histogram with x-axis treated as categorical
plt.bar(range(len(scc_sizes)), scc_frequencies, color='blue')
plt.xticks(range(len(scc_sizes)), scc_sizes)
plt.yscale('log')
plt.title('Strongly Connected Components Histogram')
plt.xlabel('SCC Size (Number of Nodes)')
plt.ylabel('Frequency')
plt.show()

# %%
def visualize_scc(G, scc, show_labels = False):
    
    subgraph = G.subgraph(scc)

    pos = nx.kamada_kawai_layout(subgraph)
        
    nx.draw(
            subgraph,
            pos,
            node_color='skyblue',
            node_size=100,
            font_size=6,
            font_color='black',
            font_weight='bold',
            edge_color='gray',
            linewidths=1,
            alpha=0.7
        )
     
    if show_labels:
            
        label_pos = {k: (x, y - 0.12) for k, (x, y) in pos.items()}
        nx.draw_networkx_labels(subgraph, label_pos, font_size=6, font_color='black', font_weight='bold')

    
    plt.title('Connected Component Visualization')
    plt.show()

# %%
visualize_scc(G, all_scc[0])

# %%
all_scc[0]
# Out:
# {3840,
#  43763,
#  798536,
#  896141,
#  2030711,
#  2200781,
#  2723411,
#  3586271,
#  4004901,
#  4107711,
#  5022271,
#  5404442,
#  5686612,
#  5763262,
#  5867132,
#  6450372,
#  7184612,
#  7864222,
#  8467082,
#  8632762,
#  9026112,
#  9078472,
#  9571702,
#  9717472,
#  10446482,
#  11336782,
#  11471572,
#  11582012,
#  12071362,
#  12263542,
#  14095650,
#  14096763,
#  14101605,
#  14123881,
#  14182218,
#  14196108,
#  14285961,
#  14334846,
#  14379660,
#  14562285,
#  14592709,
#  14654085,
#  14723614,
#  14814762,
#  14855994,
#  14931637,
#  14935367,
#  15043917,
#  15226458,
#  15250501,
#  15281391,
#  15446531,
#  15567173,
#  15672273,
#  15809138,
#  15863880,
#  15950086,
#  15985111,
#  16076032,
#  16106584,
#  16598957,
#  16783996,
#  16861509,
#  17250666,
#  17351167,
#  17702451,
#  17881764,
#  17888010,
#  17925409,
#  18189286,
#  18213426,
#  18266688,
#  18269124,
#  18300968,
#  18359716,
#  18378349,
#  18555793,
#  18686907,
#  18719020,
#  18839937,
#  18856867,
#  18946913,
#  19062153,
#  19079480,
#  19224439,
#  19546277,
#  19721574,
#  19748227,
#  19951102,
#  20169416,
#  20178419,
#  20374262,
#  20648704,
#  20656604,
#  20844341,
#  20902138,
#  21526988,
#  21696279,
#  21822997,
#  22031726,
#  22396478,
#  22681084,
#  22758405,
#  23504313,
#  23564055,
#  24127811,
#  24277551,
#  25886242,
#  25913049,
#  26136365,
#  26377478,
#  26693708,
#  27557141,
#  27900790,
#  28212513,
#  28582680,
#  29034000,
#  30192824,
#  30325257,
#  30597171,
#  30699048,
#  30766919,
#  31701010,
#  32002507,
#  32201297,
#  33774289,
#  33939145,
#  34415961,
#  35101986,
#  35415440,
#  35486890,
#  35499699,
#  35749949,
#  36619953,
#  36691434,
#  38271276,
#  38472405,
#  39207995,
#  40742821,
#  42584365,
#  43362712,
#  43579221,
#  43775786,
#  43949721,
#  44505979,
#  45817623,
#  47003920,
#  47526275,
#  47966112,
#  48093881,
#  48351615,
#  48924841,
#  50703014,
#  50976550,
#  52247685,
#  52549030,
#  53113691,
#  53712478,
#  53836928,
#  54577897,
#  56562803,
#  57268394,
#  57394106,
#  58487473,
#  61417559,
#  66106683,
#  66533920,
#  66950686,
#  68739089,
#  68854969,
#  75209239,
#  75797367,
#  79714172,
#  84172182,
#  84490044,
#  90597181,
#  92281665,
#  93524235,
#  94274445,
#  95257097,
#  96568966,
#  97239626,
#  100416493,
#  101002059,
#  108438789,
#  111533746,
#  112509659,
#  112916339,
#  116232741,
#  116328126,
#  116835497,
#  117589511,
#  118917461,
#  119837703,
#  127831036,
#  130266161,
#  138141969,
#  141145166,
#  142537400,
#  146345384,
#  149571760,
#  150755250,
#  151535146,
#  151936663,
#  153962533,
#  154950529,
#  167518667,
#  169312819,
#  170049408,
#  171035372,
#  174981490,
#  176644153,
#  177906098,
#  180212381,
#  180493678,
#  183829477,
#  185157292,
#  188103539,
#  188369814,
#  189184866,
#  189518354,
#  194499127,
#  194658182,
#  196519120,
#  198700618,
#  211106542,
#  211530941,
#  212692308,
#  213032123,
#  213811226,
#  217534944,
#  219517617,
#  221519905,
#  223162829,
#  223238349,
#  223921570,
#  227682918,
#  229866044,
#  230186350,
#  230517800,
#  231208649,
#  233027426,
#  233034400,
#  239518063,
#  241493729,
#  242169927,
#  242763001,
#  246911146,
#  247973359,
#  249469940,
#  249768777,
#  251769222,
#  256053691,
#  257019844,
#  260767065,
#  270055938,
#  281877818,
#  283627388,
#  286432534,
#  286654612,
#  292565344,
#  295218901,
#  295299583,
#  297012999,
#  302505363,
#  312643305,
#  312789382,
#  313724502,
#  314864509,
#  323327362,
#  325111978,
#  349249475,
#  352441927,
#  357193782,
#  357786278,
#  358545917,
#  359671961,
#  363005534,
#  370872518,
#  375662595,
#  375707743,
#  380664281,
#  394531684,
#  399412477,
#  410080913,
#  412587524,
#  415794343,
#  419084104,
#  421271885,
#  437179266,
#  455937214,
#  465173917,
#  467535591,
#  476786738,
#  482418675,
#  487907633,
#  493351331,
#  497174361,
#  508996367,
#  516674802,
#  534493783,
#  565579525,
#  569827550,
#  583517629,
#  611986351,
#  739119366,
#  750750349,
#  757033212,
#  760853748,
#  776636857,
#  825713234,
#  848690137,
#  857391241,
#  865427900,
#  889273682,
#  948935767,
#  1021817359,
#  1135622396,
#  1177420700,
#  1187889182,
#  1194984822,
#  1203182527,
#  1225362522,
#  1244422231,
#  1290247555,
#  1361039118,
#  1376161898,
#  1386439608,
#  1431950773,
#  1460283925,
#  1463217036,
#  1469603575,
#  1478121462,
#  1527806202,
#  1530033576,
#  1530530365,
#  1566114613,
#  1615557272,
#  1643500784,
#  1649128015,
#  1688796138,
#  1694362759,
#  1881823231,
#  1932590653,
#  1961333743,
#  2159099744,
#  2178012643,
#  2188849260,
#  2190759643,
#  2193616844,
#  2206472570,
#  2215937899,
#  2259434528,
#  2285235781,
#  2288889440,
#  2320755170,
#  2353891049,
#  2361601055,
#  2362854624,
#  2372510178,
#  2373682811,
#  2402535456,
#  2434882878,
#  2437938810,
#  2453385626,
#  2474749586,
#  2478756618,
#  2488868005,
#  2539578409,
#  2561715571,
#  2565412998,
#  2573380344,
#  2590633042,
#  2593497397,
#  2611856134,
#  2730853586,
#  2743863562,
#  2799211554,
#  2839135427,
#  2930644399,
#  2933805082,
#  2966660663,
#  3005733012,
#  3012852462,
#  3015161303,
#  3105304911,
#  3161378401,
#  3216547243,
#  3226266525,
#  3229279664,
#  3238783482,
#  3260096383,
#  3309908860,
#  3313864528,
#  3364497995,
#  3696215239,
#  3740778132,
#  3765917302,
#  3793308794,
#  3833343869,
#  3833416227,
#  4011928402,
#  4119727762,
#  4135644558,
#  4182894076,
#  4315649778,
#  4711717992,
#  702654540387127296,
#  706950859599454208,
#  710463119886262272,
#  711196955582398464,
#  711905146230476800,
#  717488895928041472,
#  723730502927175680,
#  725253338640617472,
#  725969359089229824,
#  742735530287304704,
#  744660060635271168,
#  745295911085973504,
#  755438286110195712,
#  755731653910200320,
#  766352401771134976,
#  767122751110975488,
#  771255865273823232,
#  782946231551131648,
#  789205988259704832,
#  796056596229029888,
#  801191868969013248,
#  805160271388049408,
#  820252180796100608,
#  820282353436200960,
#  823766058909761536,
#  826309082772492288,
#  826856100494528512,
#  830711834848043008,
#  832890013759262720,
#  851583986270957568,
#  864393238123343872,
#  865835753867157504,
#  867382533876576256,
#  874312616671272960,
#  875054869995896832,
#  877728873340956672,
#  877807935493033984,
#  877903433117859840,
#  887748030304329728,
#  893818632089763840,
#  894317267273560064,
#  898760033994977280,
#  899151164473790464,
#  899400132176859136,
#  902839045356744704,
#  902926941413453824,
#  905078986656673792,
#  906870773066772480,
#  918804624303382528,
#  923853191799803904,
#  931615713558634496,
#  932312228614701056,
#  935723010744553472,
#  935742315389444096,
#  938606626017370112,
#  939131942775218176,
#  940853278652411904,
#  943506806931734528,
#  944001536866312192,
#  944686196331966464,
#  945521861168914432,
#  945817135816654848,
#  947673769694416896,
#  948974801737134080,
#  950915985422221312,
#  951920334831173632,
#  954005112174862336,
#  958118843636854784,
#  958367738338140160,
#  960949527279742976,
#  961026235122958336,
#  962958900906680320,
#  971361892735291392,
#  981208355115974656,
#  984453536254713856,
#  985688130509393920,
#  987343085251317760,
#  993673575230996480,
#  995678645762093056,
#  997502650357727232,
#  999492441513148416,
#  1007733777383247872,
#  1025967921472786432,
#  1031747223569227776,
#  1032339176858050560,
#  1037045241084342272,
#  1044207764212518912,
#  1044218542453854208,
#  1051852534518824960,
#  1052829861138509824,
#  1073132650309726208,
#  1079853966681346048,
#  1096870473252642816,
#  1106274235763314688,
#  1106959667702444032,
#  1118104888393650176,
#  1123403704323805184,
#  1128606567354359808,
#  1131352246573195264,
#  1136819035163619328,
#  1170347938868076544,
#  1175650198116347904,
#  1176293728170008576,
#  1196542741871771648,
#  1205909348557426688,
#  1218258049556594688,
#  1219719960693334016,
#  1232319080637616128,
#  1252627966724648960,
#  1259032968707952640,
#  1260559704335568896,
#  1265559881588899840,
#  1270906326823186432,
#  1281457267582177280,
#  1293955372424654848,
#  1297651178256257024,
#  1301215504686694400,
#  1305502637547192320,
#  1310446297812480000,
#  1323762343302615040,
#  1326211445978144768,
#  1327343239800582144,
#  1332026809181986816,
#  1339588489537486848,
#  1344759366671589376,
#  1348722865848332288,
#  1356386110847377408,
#  1386510948790202368,
#  1395485033155031040,
#  1401047579647954944,
#  1402397565425967104,
#  1405362161229119488,
#  1425531375751421952,
#  1433042511128416256,
#  1439692694880591872,
#  1446715714082115584,
#  1450882486372913152,
#  1451036242431262720,
#  1457997372055752704,
#  1470812043385049088,
#  1484117053892141056,
#  1492510878323081216,
#  1495917535354626048,
#  1496027288294592512,
#  1509533768759103488,
#  1527288227714899968,
#  1530667470947856384,
#  1542716844758355968,
#  1550192484721905664,
#  1574337751885156352,
#  1577494050906816512,
#  1578844681819099136,
#  1582468777270198272,
#  1590026842735403008,
#  1590027083350261760,
#  1590146886815580160,
#  1592499357336616960,
#  1592592299564957696}

# %%
df[df['user.id'] == 3586271]
# Out:
#                            created_at  \
# 94687  Fri Nov 11 12:40:14 +0000 2022
# 80438  Thu Nov 10 01:04:37 +0000 2022
# 40835  Wed Nov 09 23:33:25 +0000 2022
# 82149  Fri Nov 11 18:33:50 +0000 2022
# 3002   Mon Nov 14 14:36:49 +0000 2022
# 97596  Sat Nov 12 01:39:12 +0000 2022
# 66536  Mon Nov 14 02:13:31 +0000 2022
# 61355  Sat Nov 12 14:00:07 +0000 2022
# 86170  Sat Nov 12 02:59:31 +0000 2022
# 22525  Sun Nov 13 20:59:30 +0000 2022
# 7836   Thu Nov 17 14:29:00 +0000 2022
# 65269  Wed Nov 23 01:38:37 +0000 2022
# 94607  Wed Nov 23 02:08:48 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 94687  You may think that all centralized exchanges a...               0
# 80438  The thing that bothers me most about these col...               7
# 40835                                                NaN               0
# 82149                                                NaN               0
# 3002   It took a few bean bag chairs and billions of ...               0
# 97596  I have deep respect for principled people in c...               0
# 66536                                                NaN               0
# 61355  Stop this bullshit about custody of funds bein...               0
# 86170  One of the big reasons our business wasn’t abl...              13
# 22525  Only way to take your mind off one of the shit...               0
# 7836                                                 NaN               0
# 65269  It kind of feels weird that @binance is out he...               0
# 94607  If you think the only person finding shady way...               1
#
#                                                full_text  geo geo.coordinates  \
# 94687  You may think that all centralized exchanges a...  NaN             NaN
# 80438  The thing that bothers me most about these col...  NaN             NaN
# 40835  In a way @cobie he was trying to bankrupt thes...  NaN             NaN
# 82149  so long as i don't have to have a laborious bl...  NaN             NaN
# 3002   It took a few bean bag chairs and billions of ...  NaN             NaN
# 97596  I have deep respect for principled people in c...  NaN             NaN
# 66536  Somehow we’ve managed to allow Bitboy to escap...  NaN             NaN
# 61355  Stop this bullshit about custody of funds bein...  NaN             NaN
# 86170  One of the big reasons our business wasn’t abl...  NaN             NaN
# 22525  Only way to take your mind off one of the shit...  NaN             NaN
# 7836   Would love to get some details from those addi...  NaN             NaN
# 65269  It kind of feels weird that @binance is out he...  NaN             NaN
# 94607  If you think the only person finding shady way...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 94687      NaN  1591048152110755842            0
# 80438      NaN  1590510705132068864            0
# 40835      NaN  1590487755586678785            0
# 82149      NaN  1591137138678063104            0
# 3002       NaN  1592164656743075841            0
# 97596      NaN  1591244186186969088            0
# 66536      NaN  1591977599592730624            0
# 61355      NaN  1591430643501903872            0
# 86170      NaN  1591264400488689664            0
# 22525      NaN  1591898571208790016            0
# 7836       NaN  1593249851055435786            0
# 65269      NaN  1595230304276566018            0
# 94607      NaN  1595237902874812417            0
#
#              quoted_status.created_at  ... truncated  \
# 94687                             NaN  ...      True
# 80438                             NaN  ...      True
# 40835  Sat Nov 05 18:43:11 +0000 2022  ...     False
# 82149  Fri Nov 11 16:37:43 +0000 2022  ...     False
# 3002                              NaN  ...      True
# 97596                             NaN  ...      True
# 66536                             NaN  ...     False
# 61355                             NaN  ...      True
# 86170                             NaN  ...      True
# 22525                             NaN  ...      True
# 7836   Thu Nov 17 14:24:56 +0000 2022  ...     False
# 65269                             NaN  ...      True
# 94607                             NaN  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 94687                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 80438                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 40835                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 82149                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 3002                                NaN  Fri Apr 06 03:57:54 +0000 2007
# 97596                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 66536                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 61355                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 86170                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 22525                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 7836                                NaN  Fri Apr 06 03:57:54 +0000 2007
# 65269                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 94607                               NaN  Fri Apr 06 03:57:54 +0000 2007
#
#        user.followers_count  user.friends_count  user.geo_enabled  user.id  \
# 94687                 26532                2695              True  3586271
# 80438                 26538                2695              True  3586271
# 40835                 26509                2692              True  3586271
# 82149                 26533                2697              True  3586271
# 3002                  26512                2699              True  3586271
# 97596                 26534                2696              True  3586271
# 66536                 26514                2699              True  3586271
# 61355                 26532                2697              True  3586271
# 86170                 26524                2699              True  3586271
# 22525                 26519                2699              True  3586271
# 7836                  26503                2700              True  3586271
# 65269                 26475                2699              True  3586271
# 94607                 26471                2710              True  3586271
#
#        user.location quoted_status.geo.coordinates  quoted_status.geo.type
# 94687  Virginia, USA                           NaN                     NaN
# 80438  Virginia, USA                           NaN                     NaN
# 40835  Virginia, USA                           NaN                     NaN
# 82149  Virginia, USA                           NaN                     NaN
# 3002   Virginia, USA                           NaN                     NaN
# 97596  Virginia, USA                           NaN                     NaN
# 66536  Virginia, USA                           NaN                     NaN
# 61355  Virginia, USA                           NaN                     NaN
# 86170  Virginia, USA                           NaN                     NaN
# 22525  Virginia, USA                           NaN                     NaN
# 7836   Virginia, USA                           NaN                     NaN
# 65269  Virginia, USA                           NaN                     NaN
# 94607  Virginia, USA                           NaN                     NaN
#
# [13 rows x 39 columns]

# %%
visualize_scc(G, all_scc[1])

# %%
all_scc[1]
# Out:
# {825202871427751936,
#  912957684852318208,
#  1510467423362637824,
#  1517168776977915904,
#  1517170926651166720,
#  1518663117966049280,
#  1518981680060461056,
#  1518983855730212864,
#  1518993327513047040,
#  1519152370491437056,
#  1520268892345577472,
#  1520269534434758656,
#  1520812629660372992,
#  1521694472479952896,
#  1522011986514440192,
#  1522506688842010624,
#  1522822906023088128,
#  1526593404473249792,
#  1548336466639884288,
#  1548680749213106176,
#  1549619001365790720,
#  1563756343370035200,
#  1563814773254660096,
#  1566883966656819200,
#  1574611704805150720}

# %%
df[df['user.id'] == 1518981680060461056]
# Out:
#                            created_at  \
# 80421  Wed Nov 09 04:27:18 +0000 2022
# 62089  Tue Nov 08 08:18:30 +0000 2022
# 11943  Wed Nov 09 00:49:08 +0000 2022
# 93360  Wed Nov 09 04:35:34 +0000 2022
# 62176  Wed Nov 09 04:29:40 +0000 2022
# ...                               ...
# 40593  Mon Nov 21 00:58:38 +0000 2022
# 86397  Wed Nov 23 01:46:52 +0000 2022
# 94849  Wed Nov 23 15:19:37 +0000 2022
# 2649   Tue Nov 22 05:33:26 +0000 2022
# 4299   Wed Nov 23 01:50:56 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 80421  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               8
# 62089  @VIKASTR64858110 @therahulads @BrijSharma1980 ...               5
# 11943  @RunadVNZLX @djtakefive @PrinceDionysos @Black...              12
# 93360  @VIKASTR64858110 @therahulads @BrijSharma1980 ...               3
# 62176  @BrijSharma1980 @therahulads @CryptoAdsIndia @...              12
# ...                                                  ...             ...
# 40593  #ADSCOIN is the Future of #Crypto World. Comin...              83
# 86397  #ADSCOIN is the Future of #Crypto World. Comin...              19
# 94849  @Yogeshmistari59 @therahulads @CryptoAdsIndia ...               5
# 2649   #ADSCOIN is the Future of #Crypto World. Comin...              75
# 4299   @RAJESHK51744319 @therahulads @BrijSharma1980 ...              10
#
#                                                full_text  geo geo.coordinates  \
# 80421  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 62089  @VIKASTR64858110 @therahulads @BrijSharma1980 ...  NaN             NaN
# 11943  @RunadVNZLX @djtakefive @PrinceDionysos @Black...  NaN             NaN
# 93360  @VIKASTR64858110 @therahulads @BrijSharma1980 ...  NaN             NaN
# 62176  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# ...                                                  ...  ...             ...
# 40593  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 86397  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 94849  @Yogeshmistari59 @therahulads @CryptoAdsIndia ...  NaN             NaN
# 2649   #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 4299   @RAJESHK51744319 @therahulads @BrijSharma1980 ...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 80421      NaN  1590199325690572802            0
# 62089      NaN  1589895119779815428            0
# 11943      NaN  1590144423526293504            0
# 93360      NaN  1590201406321221632            0
# 62176      NaN  1590199921294344193            0
# ...        ...                  ...          ...
# 40593      NaN  1594495466468970496            2
# 86397      NaN  1595232382692773889            3
# 94849      NaN  1595436918531330049            0
# 2649       NaN  1594927013156257794            2
# 4299       NaN  1595233405222146048            0
#
#              quoted_status.created_at  ... truncated  \
# 80421                             NaN  ...      True
# 62089                             NaN  ...      True
# 11943                             NaN  ...      True
# 93360                             NaN  ...      True
# 62176                             NaN  ...      True
# ...                               ...  ...       ...
# 40593                             NaN  ...      True
# 86397  Tue Nov 22 00:57:12 +0000 2022  ...      True
# 94849                             NaN  ...      True
# 2649                              NaN  ...      True
# 4299                              NaN  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 80421                               NaN  Tue Apr 26 15:54:19 +0000 2022
# 62089                               NaN  Tue Apr 26 15:54:19 +0000 2022
# 11943                               NaN  Tue Apr 26 15:54:19 +0000 2022
# 93360                               NaN  Tue Apr 26 15:54:19 +0000 2022
# 62176                               NaN  Tue Apr 26 15:54:19 +0000 2022
# ...                                 ...                             ...
# 40593                               NaN  Tue Apr 26 15:54:19 +0000 2022
# 86397                               NaN  Tue Apr 26 15:54:19 +0000 2022
# 94849                               NaN  Tue Apr 26 15:54:19 +0000 2022
# 2649                                NaN  Tue Apr 26 15:54:19 +0000 2022
# 4299                                NaN  Tue Apr 26 15:54:19 +0000 2022
#
#        user.followers_count  user.friends_count  user.geo_enabled  \
# 80421                   892                 603              True
# 62089                   886                 603              True
# 11943                   887                 603              True
# 93360                   887                 603              True
# 62176                   888                 603              True
# ...                     ...                 ...               ...
# 40593                   918                 666              True
# 86397                   918                 666              True
# 94849                   918                 666              True
# 2649                    918                 666              True
# 4299                    918                 666              True
#
#                    user.id  user.location quoted_status.geo.coordinates  \
# 80421  1518981680060461056           None                          None
# 62089  1518981680060461056           None                          None
# 11943  1518981680060461056           None                          None
# 93360  1518981680060461056           None                          None
# 62176  1518981680060461056           None                          None
# ...                    ...            ...                           ...
# 40593  1518981680060461056           None                          None
# 86397  1518981680060461056           None                          None
# 94849  1518981680060461056           None                          None
# 2649   1518981680060461056           None                          None
# 4299   1518981680060461056           None                          None
#
#        quoted_status.geo.type
# 80421                    None
# 62089                    None
# 11943                    None
# 93360                    None
# 62176                    None
# ...                       ...
# 40593                    None
# 86397                    None
# 94849                    None
# 2649                     None
# 4299                     None
#
# [122 rows x 39 columns]

# %%
visualize_scc(G, all_scc[2])

# %%
all_scc[2]
# Out:
# {132146668,
#  302686882,
#  407861358,
#  1373794038,
#  2366663978,
#  2539284575,
#  2884498638,
#  3196973563,
#  3247613569,
#  3346348648,
#  4921730335,
#  706347814960259072,
#  876757408038572032,
#  950621345544482816,
#  1236599199103201280,
#  1536572639321661440,
#  1568207259628638208,
#  1578441484923199488,
#  1582049279023415296,
#  1588568332160012288,
#  1592585215859650560}

# %%
df[df['user.id'] == 3196973563]
# Out:
#                            created_at  \
# 82952  Sat Nov 19 03:02:49 +0000 2022
# 85994  Sat Nov 19 03:08:54 +0000 2022
# 2162   Fri Nov 18 10:18:13 +0000 2022
# 8299   Sat Nov 19 03:58:21 +0000 2022
# 72487  Fri Nov 18 17:04:41 +0000 2022
# 5767   Fri Nov 18 17:14:23 +0000 2022
# 21871  Sat Nov 19 04:01:16 +0000 2022
# 31411  Sat Nov 19 01:37:51 +0000 2022
# 59622  Sat Nov 19 03:02:02 +0000 2022
# 10042  Fri Nov 18 16:01:49 +0000 2022
# 13160  Fri Nov 18 04:11:05 +0000 2022
# 34670  Sat Nov 19 04:01:49 +0000 2022
# 65177  Mon Nov 21 16:08:38 +0000 2022
# 73224  Fri Nov 18 07:19:23 +0000 2022
# 73615  Fri Nov 18 07:19:55 +0000 2022
# 95522  Fri Nov 18 04:09:34 +0000 2022
# 96364  Fri Nov 18 04:10:11 +0000 2022
# 96855  Fri Nov 18 04:10:31 +0000 2022
# 98172  Fri Nov 18 04:11:27 +0000 2022
# 129    Fri Nov 18 04:12:48 +0000 2022
# 8777   Fri Nov 18 04:09:05 +0000 2022
# 36988  Tue Nov 22 13:52:30 +0000 2022
# 27842  Fri Nov 18 17:04:53 +0000 2022
# 29133  Fri Nov 18 17:14:07 +0000 2022
# 32999  Fri Nov 18 16:00:38 +0000 2022
# 93243  Fri Nov 18 10:17:38 +0000 2022
# 54637  Fri Nov 18 17:04:59 +0000 2022
# 59316  Fri Nov 18 17:08:53 +0000 2022
# 59480  Fri Nov 18 17:09:02 +0000 2022
# 65486  Fri Nov 18 17:14:00 +0000 2022
# 23399  Fri Nov 18 15:54:13 +0000 2022
# 30191  Fri Nov 18 17:04:28 +0000 2022
# 31876  Fri Nov 18 17:14:15 +0000 2022
# 23289  Fri Nov 18 10:18:02 +0000 2022
# 23474  Fri Nov 18 10:18:19 +0000 2022
# 96113  Fri Nov 18 10:15:26 +0000 2022
# 93450  Fri Nov 18 15:54:23 +0000 2022
# 99885  Fri Nov 18 16:00:14 +0000 2022
# 66     Fri Nov 18 16:00:22 +0000 2022
# 280    Fri Nov 18 16:00:31 +0000 2022
# 767    Fri Nov 18 16:00:56 +0000 2022
# 1740   Fri Nov 18 16:01:42 +0000 2022
# 37713  Fri Nov 18 11:01:19 +0000 2022
# 82479  Fri Nov 18 11:01:36 +0000 2022
# 36911  Fri Nov 18 10:15:08 +0000 2022
# 87910  Fri Nov 18 07:18:46 +0000 2022
# 92832  Tue Nov 22 13:51:32 +0000 2022
# 9487   Tue Nov 22 13:52:05 +0000 2022
# 35738  Sat Nov 19 11:29:07 +0000 2022
# 4358   Sat Nov 19 11:29:16 +0000 2022
# 4583   Sat Nov 19 15:14:37 +0000 2022
# 4697   Sat Nov 19 15:13:20 +0000 2022
# 33080  Sat Nov 19 11:29:51 +0000 2022
# 73527  Sat Nov 19 11:22:58 +0000 2022
# 73625  Sat Nov 19 11:22:40 +0000 2022
# 38313  Tue Nov 22 13:51:46 +0000 2022
# 48238  Mon Nov 21 16:01:39 +0000 2022
# 27220  Tue Nov 22 13:52:18 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 82952  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 85994  #SaveKashmiriHindus PM Package Employee’s\nAft...               0
# 2162   #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               4
# 8299   #SaveKashmiriHindus PM Package Employee’s\nAft...               0
# 72487  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...              16
# 5767   #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               5
# 21871  #SaveKashmiriHindus PM Package Employee’s\nAft...               2
# 31411  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               5
# 59622  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               1
# 10042  @NipunJalali @narendramodi @OfficeOfLGJandK @A...               0
# 13160  #Save_Kashmiri_Hindus_PM_Package_Employees\nAf...               4
# 34670  #SaveKashmiriHindus PM Package Employee’s\nAft...               1
# 65177  #Hindus_All_Over_Globe to #StandWithKashmiriHi...               0
# 73224  #Save_Kashmiri_Hindus_PM_Package_Employee\nAft...               0
# 73615  #Save_Kashmiri_Hindus_PM_Package_Employee\nAft...               0
# 95522  #Save_Kashmiri_Hindus_PM_Package_Employee\n \n...               0
# 96364  #Save_Kashmiri_Hindus_PM_Package_Employee\n\nA...               0
# 96855  #Save_Kashmiri_Hindus_PM_Package_Employees\nAf...               0
# 98172  #Save_Kashmiri_Hindus_PM_Package_Employee\n\nA...               0
# 129    #Save_Kashmiri_Hindus_PM_Package_Employee\n\nA...               0
# 8777   #Save_Kashmiri_Hindus_PM_Package_Employee\nAft...               1
# 36988  #Hindus_All_Over_Globe should \n#StandWithKash...               3
# 27842  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               2
# 29133  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               1
# 32999  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               3
# 93243  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               2
# 54637  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 59316  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 59480  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 65486  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 23399  @Rastrahit12 #Save_Kashmiri_Hindus_PM_Package_...               4
# 30191  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               2
# 31876  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               3
# 23289  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 23474  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 96113  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               2
# 93450  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 99885  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 66     #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 280    #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 767    #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 1740   #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 37713  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               2
# 82479  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               0
# 36911  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...               5
# 87910  @bleedingcmty @narendramodi @PMOIndia @AmitSha...               0
# 92832  #Hindus_All_Over_Globe should \n#StandWithKash...               1
# 9487   #Hindus_All_Over_Globe should \n#StandWithKash...               4
# 35738  #SaveKashmiriHindus PM Package Employee’s\nAft...               3
# 4358   #SaveKashmiriHindus PM Package Employee’s\nAft...               5
# 4583   #SaveKashmiriHindus PM Package Employee’s \nTi...               4
# 4697   #SaveKashmiriHindus PM Package Employee’s \nTi...               3
# 33080  #SaveKashmiriHindus PM Package Employee’s\nAft...               3
# 73527  #SaveKashmiriHindus PM Package Employee’s\nAft...               3
# 73625  #SaveKashmiriHindus PM Package Employee’s\nAft...               2
# 38313  #Hindus_All_Over_Globe should \n#StandWithKash...               1
# 48238  #Hindus_All_Over_Globe to #StandWithKashmiriHi...               7
# 27220  #Hindus_All_Over_Globe should \n#StandWithKash...               0
#
#                                                full_text  geo geo.coordinates  \
# 82952  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 85994  #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 2162   #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 8299   #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 72487  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 5767   #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 21871  #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 31411  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 59622  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 10042  @NipunJalali @narendramodi @OfficeOfLGJandK @A...  NaN             NaN
# 13160  #Save_Kashmiri_Hindus_PM_Package_Employees\nAf...  NaN             NaN
# 34670  #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 65177  #Hindus_All_Over_Globe to #StandWithKashmiriHi...  NaN             NaN
# 73224  #Save_Kashmiri_Hindus_PM_Package_Employee\nAft...  NaN             NaN
# 73615  #Save_Kashmiri_Hindus_PM_Package_Employee\nAft...  NaN             NaN
# 95522  #Save_Kashmiri_Hindus_PM_Package_Employee\n \n...  NaN             NaN
# 96364  #Save_Kashmiri_Hindus_PM_Package_Employee\n\nA...  NaN             NaN
# 96855  #Save_Kashmiri_Hindus_PM_Package_Employees\nAf...  NaN             NaN
# 98172  #Save_Kashmiri_Hindus_PM_Package_Employee\n\nA...  NaN             NaN
# 129    #Save_Kashmiri_Hindus_PM_Package_Employee\n\nA...  NaN             NaN
# 8777   #Save_Kashmiri_Hindus_PM_Package_Employee\nAft...  NaN             NaN
# 36988  #Hindus_All_Over_Globe should \n#StandWithKash...  NaN             NaN
# 27842  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 29133  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 32999  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 93243  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 54637  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 59316  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 59480  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 65486  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 23399  @Rastrahit12 #Save_Kashmiri_Hindus_PM_Package_...  NaN             NaN
# 30191  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 31876  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 23289  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 23474  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 96113  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 93450  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 99885  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 66     #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 280    #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 767    #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 1740   #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 37713  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 82479  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 36911  #Save_Kashmiri_Hindus_PM_Package_Employee .. \...  NaN             NaN
# 87910  @bleedingcmty @narendramodi @PMOIndia @AmitSha...  NaN             NaN
# 92832  #Hindus_All_Over_Globe should \n#StandWithKash...  NaN             NaN
# 9487   #Hindus_All_Over_Globe should \n#StandWithKash...  NaN             NaN
# 35738  #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 4358   #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 4583   #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 4697   #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 33080  #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 73527  #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 73625  #SaveKashmiriHindus PM Package Employee’s\nAft...  NaN             NaN
# 38313  #Hindus_All_Over_Globe should \n#StandWithKash...  NaN             NaN
# 48238  #Hindus_All_Over_Globe to #StandWithKashmiriHi...  NaN             NaN
# 27220  #Hindus_All_Over_Globe should \n#StandWithKash...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 82952      NaN  1593801945277689856            0
# 85994      NaN  1593803476936847360            0
# 2162       NaN  1593549126473773061            2
# 8299       NaN  1593815918744076288            0
# 72487      NaN  1593651418506067968            4
# 5767       NaN  1593653860056567808            2
# 21871      NaN  1593816652650811393            0
# 31411      NaN  1593780561067540480            0
# 59622      NaN  1593801748506083329            0
# 10042      NaN  1593635598950371330            0
# 13160      NaN  1593456734474903552            1
# 34670      NaN  1593816792543395840            0
# 65177      NaN  1594724476692094976            0
# 73224      NaN  1593504122288078848            0
# 73615      NaN  1593504258959503360            0
# 95522      NaN  1593456355368914945            0
# 96364      NaN  1593456508519739392            0
# 96855      NaN  1593456593093668864            0
# 98172      NaN  1593456827655913473            0
# 129        NaN  1593457168606691329            0
# 8777       NaN  1593456234308698113            0
# 36988      NaN  1595052605490987008            0
# 27842      NaN  1593651468024041472            1
# 29133      NaN  1593653793681739776            0
# 32999      NaN  1593635298592034816            1
# 93243      NaN  1593548980587499520            1
# 54637      NaN  1593651495006015488            0
# 59316      NaN  1593652474451488768            0
# 59480      NaN  1593652514679058433            0
# 65486      NaN  1593653761482059776            0
# 23399      NaN  1593633684485468160            5
# 30191      NaN  1593651365511069696            0
# 31876      NaN  1593653825231278081            0
# 23289      NaN  1593549080453869573            0
# 23474      NaN  1593549151920599042            0
# 96113      NaN  1593548428004708352            1
# 93450      NaN  1593633725581262849            0
# 99885      NaN  1593635199728103424            0
# 66         NaN  1593635231378337792            0
# 280        NaN  1593635270498594816            0
# 767        NaN  1593635376291524608            0
# 1740       NaN  1593635569799954432            0
# 37713      NaN  1593559972461580292            1
# 82479      NaN  1593560044465188864            0
# 36911      NaN  1593548351878074369            2
# 87910      NaN  1593503966176112640            0
# 92832      NaN  1595052363202850818            1
# 9487       NaN  1595052502210469888            2
# 35738      NaN  1593929357625540611            2
# 4358       NaN  1593929395361783810            3
# 4583       NaN  1593986107854983171            3
# 4697       NaN  1593985785308778496            3
# 33080      NaN  1593929544427266049            2
# 73527      NaN  1593927811265630208            2
# 73625      NaN  1593927734753103872            1
# 38313      NaN  1595052423005237249            1
# 48238      NaN  1594722718972542976            3
# 27220      NaN  1595052556019200000            0
#
#              quoted_status.created_at  ... truncated  \
# 82952  Fri Nov 18 20:30:34 +0000 2022  ...      True
# 85994  Thu Nov 17 18:17:38 +0000 2022  ...      True
# 2162   Thu Nov 17 17:25:05 +0000 2022  ...      True
# 8299   Fri Nov 18 17:04:41 +0000 2022  ...      True
# 72487  Fri Nov 18 15:31:46 +0000 2022  ...      True
# 5767   Fri Nov 18 15:33:19 +0000 2022  ...      True
# 21871  Thu Nov 17 19:20:18 +0000 2022  ...      True
# 31411  Fri Nov 18 21:34:11 +0000 2022  ...      True
# 59622  Fri Nov 18 17:20:16 +0000 2022  ...      True
# 10042                             NaN  ...      True
# 13160  Thu Nov 17 15:53:16 +0000 2022  ...      True
# 34670  Tue Nov 15 14:14:34 +0000 2022  ...      True
# 65177  Mon Nov 21 16:06:47 +0000 2022  ...      True
# 73224  Thu Nov 17 17:05:10 +0000 2022  ...      True
# 73615  Thu Nov 17 15:24:41 +0000 2022  ...      True
# 95522  Thu Nov 17 17:29:36 +0000 2022  ...      True
# 96364  Thu Nov 17 17:01:26 +0000 2022  ...      True
# 96855  Thu Nov 17 17:25:47 +0000 2022  ...      True
# 98172  Thu Nov 17 15:53:16 +0000 2022  ...      True
# 129    Thu Nov 17 09:11:07 +0000 2022  ...      True
# 8777   Fri Nov 18 03:53:24 +0000 2022  ...      True
# 36988  Tue Nov 22 12:17:10 +0000 2022  ...      True
# 27842  Fri Nov 18 16:25:02 +0000 2022  ...      True
# 29133  Fri Nov 18 11:31:25 +0000 2022  ...      True
# 32999  Fri Nov 18 15:02:54 +0000 2022  ...      True
# 93243  Thu Nov 17 17:56:01 +0000 2022  ...      True
# 54637  Fri Nov 18 16:37:37 +0000 2022  ...      True
# 59316  Fri Nov 18 05:45:07 +0000 2022  ...      True
# 59480  Fri Nov 18 17:05:32 +0000 2022  ...      True
# 65486  Fri Nov 18 16:08:34 +0000 2022  ...      True
# 23399                             NaN  ...      True
# 30191  Fri Nov 18 16:04:33 +0000 2022  ...      True
# 31876  Thu Nov 17 19:31:09 +0000 2022  ...      True
# 23289  Thu Nov 17 17:22:13 +0000 2022  ...      True
# 23474  Thu Nov 17 17:25:32 +0000 2022  ...      True
# 96113  Thu Nov 17 16:41:25 +0000 2022  ...      True
# 93450  Fri Nov 18 14:50:05 +0000 2022  ...      True
# 99885  Fri Nov 18 14:48:01 +0000 2022  ...      True
# 66     Fri Nov 18 15:54:13 +0000 2022  ...      True
# 280    Fri Nov 18 15:20:03 +0000 2022  ...      True
# 767    Fri Nov 18 14:54:32 +0000 2022  ...      True
# 1740   Fri Nov 18 16:00:45 +0000 2022  ...      True
# 37713  Fri Nov 18 10:15:08 +0000 2022  ...      True
# 82479  Thu Nov 17 17:58:53 +0000 2022  ...      True
# 36911  Tue Nov 15 14:14:34 +0000 2022  ...      True
# 87910                             NaN  ...      True
# 92832  Tue Nov 22 13:27:24 +0000 2022  ...      True
# 9487   Tue Nov 22 12:55:52 +0000 2022  ...      True
# 35738  Fri Nov 18 14:22:11 +0000 2022  ...      True
# 4358   Fri Nov 18 14:22:29 +0000 2022  ...      True
# 4583   Sat Nov 19 13:18:21 +0000 2022  ...      True
# 4697   Sat Nov 19 15:02:32 +0000 2022  ...      True
# 33080  Fri Nov 18 14:31:28 +0000 2022  ...      True
# 73527  Fri Nov 18 14:21:26 +0000 2022  ...      True
# 73625  Fri Nov 18 14:24:23 +0000 2022  ...      True
# 38313  Tue Nov 22 13:50:32 +0000 2022  ...      True
# 48238  Mon Nov 21 15:30:27 +0000 2022  ...      True
# 27220  Mon Nov 21 17:52:40 +0000 2022  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 82952                               NaN  Sat May 16 04:12:39 +0000 2015
# 85994                               NaN  Sat May 16 04:12:39 +0000 2015
# 2162                                NaN  Sat May 16 04:12:39 +0000 2015
# 8299                                NaN  Sat May 16 04:12:39 +0000 2015
# 72487                               NaN  Sat May 16 04:12:39 +0000 2015
# 5767                                NaN  Sat May 16 04:12:39 +0000 2015
# 21871                               NaN  Sat May 16 04:12:39 +0000 2015
# 31411                               NaN  Sat May 16 04:12:39 +0000 2015
# 59622                               NaN  Sat May 16 04:12:39 +0000 2015
# 10042                               NaN  Sat May 16 04:12:39 +0000 2015
# 13160                               NaN  Sat May 16 04:12:39 +0000 2015
# 34670                               NaN  Sat May 16 04:12:39 +0000 2015
# 65177                               NaN  Sat May 16 04:12:39 +0000 2015
# 73224                               NaN  Sat May 16 04:12:39 +0000 2015
# 73615                               NaN  Sat May 16 04:12:39 +0000 2015
# 95522                               NaN  Sat May 16 04:12:39 +0000 2015
# 96364                               NaN  Sat May 16 04:12:39 +0000 2015
# 96855                               NaN  Sat May 16 04:12:39 +0000 2015
# 98172                               NaN  Sat May 16 04:12:39 +0000 2015
# 129                                 NaN  Sat May 16 04:12:39 +0000 2015
# 8777                                NaN  Sat May 16 04:12:39 +0000 2015
# 36988                               NaN  Sat May 16 04:12:39 +0000 2015
# 27842                               NaN  Sat May 16 04:12:39 +0000 2015
# 29133                               NaN  Sat May 16 04:12:39 +0000 2015
# 32999                               NaN  Sat May 16 04:12:39 +0000 2015
# 93243                               NaN  Sat May 16 04:12:39 +0000 2015
# 54637                               NaN  Sat May 16 04:12:39 +0000 2015
# 59316                               NaN  Sat May 16 04:12:39 +0000 2015
# 59480                               NaN  Sat May 16 04:12:39 +0000 2015
# 65486                               NaN  Sat May 16 04:12:39 +0000 2015
# 23399                               NaN  Sat May 16 04:12:39 +0000 2015
# 30191                               NaN  Sat May 16 04:12:39 +0000 2015
# 31876                               NaN  Sat May 16 04:12:39 +0000 2015
# 23289                               NaN  Sat May 16 04:12:39 +0000 2015
# 23474                               NaN  Sat May 16 04:12:39 +0000 2015
# 96113                               NaN  Sat May 16 04:12:39 +0000 2015
# 93450                               NaN  Sat May 16 04:12:39 +0000 2015
# 99885                               NaN  Sat May 16 04:12:39 +0000 2015
# 66                                  NaN  Sat May 16 04:12:39 +0000 2015
# 280                                 NaN  Sat May 16 04:12:39 +0000 2015
# 767                                 NaN  Sat May 16 04:12:39 +0000 2015
# 1740                                NaN  Sat May 16 04:12:39 +0000 2015
# 37713                               NaN  Sat May 16 04:12:39 +0000 2015
# 82479                               NaN  Sat May 16 04:12:39 +0000 2015
# 36911                               NaN  Sat May 16 04:12:39 +0000 2015
# 87910                               NaN  Sat May 16 04:12:39 +0000 2015
# 92832                               NaN  Sat May 16 04:12:39 +0000 2015
# 9487                                NaN  Sat May 16 04:12:39 +0000 2015
# 35738                               NaN  Sat May 16 04:12:39 +0000 2015
# 4358                                NaN  Sat May 16 04:12:39 +0000 2015
# 4583                                NaN  Sat May 16 04:12:39 +0000 2015
# 4697                                NaN  Sat May 16 04:12:39 +0000 2015
# 33080                               NaN  Sat May 16 04:12:39 +0000 2015
# 73527                               NaN  Sat May 16 04:12:39 +0000 2015
# 73625                               NaN  Sat May 16 04:12:39 +0000 2015
# 38313                               NaN  Sat May 16 04:12:39 +0000 2015
# 48238                               NaN  Sat May 16 04:12:39 +0000 2015
# 27220                               NaN  Sat May 16 04:12:39 +0000 2015
#
#        user.followers_count  user.friends_count  user.geo_enabled     user.id  \
# 82952                    70                 268              True  3196973563
# 85994                    70                 268              True  3196973563
# 2162                     70                 268              True  3196973563
# 8299                     70                 268              True  3196973563
# 72487                    70                 268              True  3196973563
# 5767                     70                 268              True  3196973563
# 21871                    70                 268              True  3196973563
# 31411                    70                 268              True  3196973563
# 59622                    71                 269              True  3196973563
# 10042                    69                 268              True  3196973563
# 13160                    69                 268              True  3196973563
# 34670                    71                 269              True  3196973563
# 65177                    71                 268              True  3196973563
# 73224                    68                 268              True  3196973563
# 73615                    68                 268              True  3196973563
# 95522                    69                 268              True  3196973563
# 96364                    69                 268              True  3196973563
# 96855                    69                 268              True  3196973563
# 98172                    69                 268              True  3196973563
# 129                      69                 268              True  3196973563
# 8777                     69                 267              True  3196973563
# 36988                    70                 269              True  3196973563
# 27842                    69                 268              True  3196973563
# 29133                    69                 268              True  3196973563
# 32999                    69                 268              True  3196973563
# 93243                    69                 267              True  3196973563
# 54637                    69                 268              True  3196973563
# 59316                    69                 268              True  3196973563
# 59480                    69                 268              True  3196973563
# 65486                    69                 268              True  3196973563
# 23399                    69                 267              True  3196973563
# 30191                    69                 267              True  3196973563
# 31876                    69                 267              True  3196973563
# 23289                    68                 268              True  3196973563
# 23474                    68                 268              True  3196973563
# 96113                    68                 267              True  3196973563
# 93450                    69                 268              True  3196973563
# 99885                    69                 268              True  3196973563
# 66                       69                 268              True  3196973563
# 280                      69                 268              True  3196973563
# 767                      69                 268              True  3196973563
# 1740                     69                 268              True  3196973563
# 37713                    68                 268              True  3196973563
# 82479                    68                 268              True  3196973563
# 36911                    69                 268              True  3196973563
# 87910                    68                 267              True  3196973563
# 92832                    71                 268              True  3196973563
# 9487                     71                 269              True  3196973563
# 35738                    71                 268              True  3196973563
# 4358                     71                 268              True  3196973563
# 4583                     71                 268              True  3196973563
# 4697                     71                 268              True  3196973563
# 33080                    71                 268              True  3196973563
# 73527                    70                 267              True  3196973563
# 73625                    70                 268              True  3196973563
# 38313                    71                 268              True  3196973563
# 48238                    71                 267              True  3196973563
# 27220                    70                 269              True  3196973563
#
#                        user.location quoted_status.geo.coordinates  \
# 82952  Jammu, Jammu & Kashmir, India                           NaN
# 85994  Jammu, Jammu & Kashmir, India                           NaN
# 2162   Jammu, Jammu & Kashmir, India                           NaN
# 8299   Jammu, Jammu & Kashmir, India                           NaN
# 72487  Jammu, Jammu & Kashmir, India                           NaN
# 5767   Jammu, Jammu & Kashmir, India                           NaN
# 21871  Jammu, Jammu & Kashmir, India                           NaN
# 31411  Jammu, Jammu & Kashmir, India                           NaN
# 59622  Jammu, Jammu & Kashmir, India                           NaN
# 10042  Jammu, Jammu & Kashmir, India                           NaN
# 13160  Jammu, Jammu & Kashmir, India                           NaN
# 34670  Jammu, Jammu & Kashmir, India                           NaN
# 65177  Jammu, Jammu & Kashmir, India                           NaN
# 73224  Jammu, Jammu & Kashmir, India                           NaN
# 73615  Jammu, Jammu & Kashmir, India                           NaN
# 95522  Jammu, Jammu & Kashmir, India                           NaN
# 96364  Jammu, Jammu & Kashmir, India                           NaN
# 96855  Jammu, Jammu & Kashmir, India                           NaN
# 98172  Jammu, Jammu & Kashmir, India                           NaN
# 129    Jammu, Jammu & Kashmir, India                           NaN
# 8777   Jammu, Jammu & Kashmir, India                           NaN
# 36988  Jammu, Jammu & Kashmir, India                           NaN
# 27842  Jammu, Jammu & Kashmir, India                           NaN
# 29133  Jammu, Jammu & Kashmir, India                           NaN
# 32999  Jammu, Jammu & Kashmir, India                           NaN
# 93243  Jammu, Jammu & Kashmir, India                           NaN
# 54637  Jammu, Jammu & Kashmir, India                           NaN
# 59316  Jammu, Jammu & Kashmir, India                           NaN
# 59480  Jammu, Jammu & Kashmir, India                           NaN
# 65486  Jammu, Jammu & Kashmir, India                           NaN
# 23399  Jammu, Jammu & Kashmir, India                           NaN
# 30191  Jammu, Jammu & Kashmir, India                           NaN
# 31876  Jammu, Jammu & Kashmir, India                           NaN
# 23289  Jammu, Jammu & Kashmir, India                           NaN
# 23474  Jammu, Jammu & Kashmir, India                           NaN
# 96113  Jammu, Jammu & Kashmir, India                           NaN
# 93450  Jammu, Jammu & Kashmir, India                           NaN
# 99885  Jammu, Jammu & Kashmir, India                           NaN
# 66     Jammu, Jammu & Kashmir, India                           NaN
# 280    Jammu, Jammu & Kashmir, India                           NaN
# 767    Jammu, Jammu & Kashmir, India                           NaN
# 1740   Jammu, Jammu & Kashmir, India                           NaN
# 37713  Jammu, Jammu & Kashmir, India                           NaN
# 82479  Jammu, Jammu & Kashmir, India                           NaN
# 36911  Jammu, Jammu & Kashmir, India                           NaN
# 87910  Jammu, Jammu & Kashmir, India                           NaN
# 92832  Jammu, Jammu & Kashmir, India                           NaN
# 9487   Jammu, Jammu & Kashmir, India                           NaN
# 35738  Jammu, Jammu & Kashmir, India                           NaN
# 4358   Jammu, Jammu & Kashmir, India                           NaN
# 4583   Jammu, Jammu & Kashmir, India                           NaN
# 4697   Jammu, Jammu & Kashmir, India                           NaN
# 33080  Jammu, Jammu & Kashmir, India                           NaN
# 73527  Jammu, Jammu & Kashmir, India                           NaN
# 73625  Jammu, Jammu & Kashmir, India                           NaN
# 38313  Jammu, Jammu & Kashmir, India                           NaN
# 48238  Jammu, Jammu & Kashmir, India                           NaN
# 27220  Jammu, Jammu & Kashmir, India                           NaN
#
#        quoted_status.geo.type
# 82952                     NaN
# 85994                     NaN
# 2162                      NaN
# 8299                      NaN
# 72487                     NaN
# 5767                      NaN
# 21871                     NaN
# 31411                     NaN
# 59622                     NaN
# 10042                     NaN
# 13160                     NaN
# 34670                     NaN
# 65177                     NaN
# 73224                     NaN
# 73615                     NaN
# 95522                     NaN
# 96364                     NaN
# 96855                     NaN
# 98172                     NaN
# 129                       NaN
# 8777                      NaN
# 36988                     NaN
# 27842                     NaN
# 29133                     NaN
# 32999                     NaN
# 93243                     NaN
# 54637                     NaN
# 59316                     NaN
# 59480                     NaN
# 65486                     NaN
# 23399                     NaN
# 30191                     NaN
# 31876                     NaN
# 23289                     NaN
# 23474                     NaN
# 96113                     NaN
# 93450                     NaN
# 99885                     NaN
# 66                        NaN
# 280                       NaN
# 767                       NaN
# 1740                      NaN
# 37713                     NaN
# 82479                     NaN
# 36911                     NaN
# 87910                     NaN
# 92832                     NaN
# 9487                      NaN
# 35738                     NaN
# 4358                      NaN
# 4583                      NaN
# 4697                      NaN
# 33080                     NaN
# 73527                     NaN
# 73625                     NaN
# 38313                     NaN
# 48238                     NaN
# 27220                     NaN
#
# [58 rows x 39 columns]

# %%
visualize_scc(G, all_scc[3])

# %%
all_scc[3]
# Out:
# {5533262,
#  6068692,
#  7910872,
#  25570572,
#  85636440,
#  372650546,
#  931179333607215104,
#  1051710088098996224,
#  1117689210566316032,
#  1314846469128585216,
#  1471733556989018112}

# %%
df[df['user.id'] == 5533262]
# Out:
#                            created_at  \
# 46262  Fri Nov 11 11:22:11 +0000 2022
# 49540  Fri Nov 11 07:55:40 +0000 2022
# 64434  Fri Nov 11 06:39:55 +0000 2022
# 28478  Wed Nov 09 21:24:51 +0000 2022
# 92692  Wed Nov 09 19:29:23 +0000 2022
# ...                               ...
# 32471  Tue Nov 22 08:30:53 +0000 2022
# 17273  Tue Nov 22 05:06:53 +0000 2022
# 39397  Wed Nov 23 12:22:59 +0000 2022
# 65515  Wed Nov 23 14:03:12 +0000 2022
# 81217  Wed Nov 23 12:01:53 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 46262  @TravellerNow @sedane94 @binance can, but woul...               0
# 49540                                                NaN               6
# 64434                                                NaN               0
# 28478  @danhwang88 Improve cosmos by distributing inf...               0
# 92692                                                NaN               0
# ...                                                  ...             ...
# 32471  This is incredibly good information on decentr...               0
# 17273  our team missed an osmosis upgrade.\n\nas a va...               0
# 39397                                                NaN               5
# 65515  I think more validators should be working on t...               2
# 81217  Stake with @notionaldao for some tech and stak...              20
#
#                                                full_text  geo geo.coordinates  \
# 46262  @TravellerNow @sedane94 @binance can, but woul...  NaN             NaN
# 49540              Noticing good stuff from cosmos news.  NaN             NaN
# 64434  Install the electric fence around cosmos and I...  NaN             NaN
# 28478  @danhwang88 Improve cosmos by distributing inf...  NaN             NaN
# 92692  this was posted in the cosmos hub public chat....  NaN             NaN
# ...                                                  ...  ...             ...
# 32471  This is incredibly good information on decentr...  NaN             NaN
# 17273  our team missed an osmosis upgrade.\n\nas a va...  NaN             NaN
# 39397  The Cosmos Hub community is unique in that you...  NaN             NaN
# 65515  I think more validators should be working on t...  NaN             NaN
# 81217  Stake with @notionaldao for some tech and stak...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 46262      NaN  1591028509195251712            0
# 49540      NaN  1590976539151433728            0
# 64434      NaN  1590957477574905857            0
# 28478      NaN  1590455400306192385            0
# 92692      NaN  1590426342696574977            0
# ...        ...                  ...          ...
# 32471      NaN  1594971667167850498            0
# 17273      NaN  1594920329285365763            0
# 39397      NaN  1595392466139897862            0
# 65515      NaN  1595417684425920512            0
# 81217      NaN  1595387157807788032            0
#
#              quoted_status.created_at  ... truncated  \
# 46262                             NaN  ...      True
# 49540  Thu Nov 10 20:08:07 +0000 2022  ...     False
# 64434                             NaN  ...     False
# 28478  Wed Nov 09 19:25:14 +0000 2022  ...      True
# 92692                             NaN  ...     False
# ...                               ...  ...       ...
# 32471  Tue Nov 22 06:04:14 +0000 2022  ...      True
# 17273                             NaN  ...      True
# 39397                             NaN  ...     False
# 65515                             NaN  ...      True
# 81217  Wed Nov 23 10:15:18 +0000 2022  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 46262                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 49540                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 64434                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 28478                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 92692                               NaN  Thu Apr 26 17:04:58 +0000 2007
# ...                                 ...                             ...
# 32471                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 17273                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 39397                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 65515                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 81217                               NaN  Thu Apr 26 17:04:58 +0000 2007
#
#        user.followers_count  user.friends_count  user.geo_enabled  user.id  \
# 46262                 11697                5479              True  5533262
# 49540                 11697                5479              True  5533262
# 64434                 11701                5479              True  5533262
# 28478                 11699                5461              True  5533262
# 92692                 11701                5461              True  5533262
# ...                     ...                 ...               ...      ...
# 32471                 12063                5515              True  5533262
# 17273                 12059                5514              True  5533262
# 39397                 12024                5519              True  5533262
# 65515                 12048                5519              True  5533262
# 81217                 12023                5518              True  5533262
#
#         user.location quoted_status.geo.coordinates  quoted_status.geo.type
# 46262  Hanoi, Vietnam                           NaN                     NaN
# 49540  Hanoi, Vietnam                           NaN                     NaN
# 64434  Hanoi, Vietnam                           NaN                     NaN
# 28478  Hanoi, Vietnam                           NaN                     NaN
# 92692  Hanoi, Vietnam                           NaN                     NaN
# ...               ...                           ...                     ...
# 32471  Hanoi, Vietnam                           NaN                     NaN
# 17273  Hanoi, Vietnam                           NaN                     NaN
# 39397  Hanoi, Vietnam                           NaN                     NaN
# 65515  Hanoi, Vietnam                           NaN                     NaN
# 81217  Hanoi, Vietnam                           NaN                     NaN
#
# [242 rows x 39 columns]

# %%
all_scc[4]
# Out:
# {1153658704782397440,
#  1413674305636950016,
#  1480208511342571520,
#  1565046338915815424,
#  1585791768808681472,
#  1588364611191029760,
#  1589535471792574464}

# %%
df[df['user.id'] == 1589535471792574464]
# Out:
#                            created_at  \
# 49115  Sat Nov 12 09:20:26 +0000 2022
# 55709  Sat Nov 12 09:32:30 +0000 2022
# 78336  Sat Nov 12 01:11:39 +0000 2022
# 17611  Thu Nov 17 06:46:51 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 49115                                                NaN               0
# 55709                                                NaN               0
# 78336                                                NaN               0
# 17611  "I've got a lot of names, actually. But hey, t...               0
#
#                                                full_text  geo geo.coordinates  \
# 49115  "Not just any, "dog" a... \n\nDrum roll please...  NaN             NaN
# 55709  combat settings installed. But once it does an...  NaN             NaN
# 78336  I think I'm a pretty bad guy myself but even I...  NaN             NaN
# 17611  "I've got a lot of names, actually. But hey, t...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 49115      NaN  1591360258043424769            0
# 55709      NaN  1591363297068322816            0
# 78336      NaN  1591237254441472000            0
# 17611      NaN  1593133548982407168            0
#
#              quoted_status.created_at  ... truncated  \
# 49115  Sat Nov 12 09:18:42 +0000 2022  ...     False
# 55709                             NaN  ...     False
# 78336  Sat Nov 12 01:10:36 +0000 2022  ...     False
# 17611  Thu Nov 17 06:27:51 +0000 2022  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 49115                               NaN  Mon Nov 07 08:29:38 +0000 2022
# 55709                               NaN  Mon Nov 07 08:29:38 +0000 2022
# 78336                               NaN  Mon Nov 07 08:29:38 +0000 2022
# 17611                               NaN  Mon Nov 07 08:29:38 +0000 2022
#
#        user.followers_count  user.friends_count  user.geo_enabled  \
# 49115                   118                 201             False
# 55709                   118                 201             False
# 78336                   116                 196             False
# 17611                   149                 236             False
#
#                    user.id  user.location quoted_status.geo.coordinates  \
# 49115  1589535471792574464     Night City                           NaN
# 55709  1589535471792574464     Night City                           NaN
# 78336  1589535471792574464     Night City                           NaN
# 17611  1589535471792574464     Night City                           NaN
#
#        quoted_status.geo.type
# 49115                     NaN
# 55709                     NaN
# 78336                     NaN
# 17611                     NaN
#
# [4 rows x 39 columns]

# %%
df.head()
# Out:
#                        created_at  \
# 0  Fri Nov 11 12:03:53 +0000 2022
# 1  Fri Nov 11 12:03:53 +0000 2022
# 2  Fri Nov 11 12:03:53 +0000 2022
# 3  Fri Nov 11 12:03:54 +0000 2022
# 4  Fri Nov 11 12:03:54 +0000 2022
#
#                             extended_tweet.full_text  favorite_count  \
# 0                                                NaN               0
# 1  Never seen such a deal for a punk since 2017! ...               0
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...               0
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...               0
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...               0
#
#                                            full_text  geo geo.coordinates  \
# 0  @0x5ab0 @Uniswap oh, missed fiat part, just sa...  NaN             NaN
# 1  Never seen such a deal for a punk since 2017! ...  NaN             NaN
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...  NaN             NaN
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...  NaN             NaN
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...  NaN             NaN
#
#   geo.type                   id  quote_count        quoted_status.created_at  \
# 0      NaN  1591039006850310148            0                             NaN
# 1      NaN  1591039006770622468            0  Fri Nov 11 11:00:59 +0000 2022
# 2      NaN  1591039006501994503            0                             NaN
# 3      NaN  1591039007357550592            0                             NaN
# 4      NaN  1591039007764668417            0                             NaN
#
#    ... truncated  truncatedquoted_status.truncated  \
# 0  ...     False                               NaN
# 1  ...      True                               NaN
# 2  ...      True                               NaN
# 3  ...      True                               NaN
# 4  ...      True                               NaN
#
#                   user.created_at  user.followers_count  user.friends_count  \
# 0  Mon Jul 11 06:36:43 +0000 2011                  7050                5554
# 1  Wed Nov 09 14:09:46 +0000 2022                     0                   2
# 2  Sun May 01 15:06:34 +0000 2022                   106                   2
# 3  Wed Dec 18 21:46:55 +0000 2013                     0                   0
# 4  Tue Oct 25 03:46:04 +0000 2022                     3                  50
#
#    user.geo_enabled              user.id   user.location  \
# 0              True            333239871  CARBONdale, CO
# 1             False  1590345908172083201     Netherlands
# 2             False  1520781667769614337      blockchain
# 3             False           2252580014            None
# 4             False  1584753080113025025            None
#
#   quoted_status.geo.coordinates  quoted_status.geo.type
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
# [5 rows x 39 columns]

# %%
df.columns
# Out:
# Index(['created_at', 'extended_tweet.full_text', 'favorite_count', 'full_text',
#        'geo', 'geo.coordinates', 'geo.type', 'id', 'quote_count',
#        'quoted_status.created_at', 'quoted_status.extended_tweet.full_text',
#        'quoted_status.favorite_count', 'quoted_status.full_text',
#        'quoted_status.geo', 'quoted_status.id', 'quoted_status.quote_count',
#        'quoted_status.reply_count', 'quoted_status.retweet_count',
#        'quoted_status.text', 'quoted_status.truncated',
#        'quoted_status.user.created_at', 'quoted_status.user.followers_count',
#        'quoted_status.user.friends_count', 'quoted_status.user.geo_enabled',
#        'quoted_status.user.id', 'quoted_status.user.location', 'reply_count',
#        'retweet_count', 'text', 'truncated',
#        'truncatedquoted_status.truncated', 'user.created_at',
#        'user.followers_count', 'user.friends_count', 'user.geo_enabled',
#        'user.id', 'user.location', 'quoted_status.geo.coordinates',
#        'quoted_status.geo.type'],
#       dtype='object')

# %%
def unique_users_count(series):
    unique_users = set(series.dropna())  # Drop NaN values and get unique user IDs
    return len(unique_users), list(unique_users)

# Group by 'full_text' and aggregate using the custom function
result = df.groupby('full_text')['user.id'].agg(unique_users_count).reset_index()

# Rename the columns for clarity
result.columns = ['full_text', 'unique_user_count', 'unique_user_ids']

print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[206], line 6
#       3     return len(unique_users), list(unique_users)
#       5 # Group by 'full_text' and aggregate using the custom function
# ----> 6 result = df.groupby('full_text')['user.id'].agg(unique_users_count).reset_index()
#       8 # Rename the columns for clarity
#       9 result.columns = ['full_text', 'unique_user_count', 'unique_user_ids']
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:289, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     286     return self._python_agg_general(func, *args, **kwargs)
#     288 try:
# --> 289     return self._python_agg_general(func, *args, **kwargs)
#     290 except KeyError:
#     291     # KeyError raised in test_groupby.test_basic is bc the func does
#     292     #  a dictionary lookup on group.name, but group name is not
#     293     #  pinned in _python_agg_general, only in _aggregate_named
#     294     result = self._aggregate_named(func, *args, **kwargs)
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:322, in SeriesGroupBy._python_agg_general(self, func, *args, **kwargs)
#     319 f = lambda x: func(x, *args, **kwargs)
#     321 obj = self._obj_with_exclusions
# --> 322 result = self.grouper.agg_series(obj, f)
#     323 res = obj._constructor(result, name=obj.name)
#     324 return self._wrap_aggregated_output(res)
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/groupby/ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     843 if len(obj) > 0 and not isinstance(obj._values, np.ndarray):
#     844     # we can preserve a little bit more aggressively with EA dtype
#     845     #  because maybe_cast_pointwise_result will do a try/except
#     846     #  with _from_sequence.  NB we are assuming here that _from_sequence
#     847     #  is sufficiently strict that it casts appropriately.
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#     853 if preserve_dtype:
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/groupby/ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     868 splitter = self._get_splitter(obj, axis=0)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#     874     if not initialized:
#     875         # We only do this validation on the first iteration
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/groupby/generic.py:319, in SeriesGroupBy._python_agg_general.<locals>.<lambda>(x)
#     317     alias = com._builtin_table_alias[func]
#     318     warn_alias_replacement(self, orig_func, alias)
# --> 319 f = lambda x: func(x, *args, **kwargs)
#     321 obj = self._obj_with_exclusions
#     322 result = self.grouper.agg_series(obj, f)
#
# Cell In[206], line 2, in unique_users_count(series)
#       1 def unique_users_count(series):
# ----> 2     unique_users = set(series.dropna())  # Drop NaN values and get unique user IDs
#       3     return len(unique_users), list(unique_users)
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/series.py:5608, in Series.dropna(self, axis, inplace, how, ignore_index)
#    5606 else:
#    5607     if not inplace:
# -> 5608         result = self.copy(deep=None)
#    5609     else:
#    5610         result = self
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/generic.py:6685, in NDFrame.copy(self, deep)
#    6553 @final
#    6554 def copy(self, deep: bool_t | None = True) -> Self:
#    6555     """
#    6556     Make a copy of this object's indices and data.
#    6557
#    (...)
#    6683     dtype: int64
#    6684     """
# -> 6685     data = self._mgr.copy(deep=deep)
#    6686     self._clear_item_cache()
#    6687     return self._constructor_from_mgr(data, axes=data.axes).__finalize__(
#    6688         self, method="copy"
#    6689     )
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/internals/managers.py:576, in BaseBlockManager.copy(self, deep)
#     573     else:
#     574         new_axes = list(self.axes)
# --> 576 res = self.apply("copy", deep=deep)
#     577 res.axes = new_axes
#     579 if self.ndim > 1:
#     580     # Avoid needing to re-compute these
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/internals/managers.py:357, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
# --> 357 out = type(self).from_blocks(result_blocks, self.axes)
#     358 return out
#
# File ~/.conda/envs/contenv/lib/python3.10/site-packages/pandas/core/internals/managers.py:1812, in SingleBlockManager.from_blocks(cls, blocks, axes)
#    1809     self.axes = [axis]
#    1810     self.blocks = (block,)
# -> 1812 @classmethod
#    1813 def from_blocks(
#    1814     cls,
#    1815     blocks: list[Block],
#    1816     axes: list[Index],
#    1817 ) -> Self:
#    1818     """
#    1819     Constructor for BlockManager and SingleBlockManager with same signature.
#    1820     """
#    1821     assert len(blocks) == 1
#
# KeyboardInterrupt:

# %%
import cudf
import cupy as cp

# Convert pandas DataFrame to cuDF DataFrame
cudf_df = cudf.from_pandas(df)

# Create a custom aggregation function for GPU
def unique_users_count_gpu(series):
    unique_users = cp.unique(series.dropna())  # Drop NaN values and get unique user IDs
    return len(unique_users), list(unique_users)

# Group by 'full_text' and aggregate using the custom function
result_gpu = cudf_df.groupby('full_text')['user.id'].agg(unique_users_count_gpu).reset_index()

# Convert cuDF DataFrame back to pandas DataFrame
result_pandas = result_gpu.to_pandas()

# Rename the columns for clarity
result_pandas.columns = ['full_text', 'unique_user_count', 'unique_user_ids']

# Display the result
print(result_pandas)
