# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from crypto_chatter.graph import *

import networkx as nx

data_source = 'twitter'
index_name = 'blockchain-interoperability-attacks'

# %%
graph = CryptoTwitterUserReplyGraph(index_name)
# Out:
# loaded graph edges in 2 seconds
# loaded cached graph data in 181 seconds
# constructed complete user graph in 196 seconds

# %%
G = graph.G

# %%
df = graph.data

# %%
len(df)
# Out:
# 16625047

# %%
df.columns
# Out:
# Index(['created_at', 'extended_tweet.full_text', 'favorite_count', 'full_text',
#        'geo', 'geo.coordinates', 'geo.type', 'id', 'quote_count',
#        'quoted_status.created_at', 'quoted_status.extended_tweet.full_text',
#        'quoted_status.favorite_count', 'quoted_status.full_text',
#        'quoted_status.geo', 'quoted_status.id', 'quoted_status.quote_count',
#        'quoted_status.reply_count', 'quoted_status.retweet_count',
#        'quoted_status.text', 'quoted_status.truncated',
#        'quoted_status.user.created_at', 'quoted_status.user.followers_count',
#        'quoted_status.user.friends_count', 'quoted_status.user.geo_enabled',
#        'quoted_status.user.id', 'quoted_status.user.location', 'reply_count',
#        'retweet_count', 'text', 'truncated',
#        'truncatedquoted_status.truncated', 'user.created_at',
#        'user.followers_count', 'user.friends_count', 'user.geo_enabled',
#        'user.id', 'user.location', 'quoted_status.geo.coordinates',
#        'quoted_status.geo.type'],
#       dtype='object')

# %%
len(G.nodes)
# Out:
# 1640251

# %%
len(G.edges)
# Out:
# 2520608

# %%
df.head()
# Out:
#                        created_at  \
# 0  Fri Nov 11 12:03:53 +0000 2022
# 1  Fri Nov 11 12:03:53 +0000 2022
# 2  Fri Nov 11 12:03:53 +0000 2022
# 3  Fri Nov 11 12:03:54 +0000 2022
# 4  Fri Nov 11 12:03:54 +0000 2022
#
#                             extended_tweet.full_text  favorite_count  \
# 0                                                NaN               0
# 1  Never seen such a deal for a punk since 2017! ...               0
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...               0
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...               0
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...               0
#
#                                            full_text  geo geo.coordinates  \
# 0  @0x5ab0 @Uniswap oh, missed fiat part, just sa...  NaN             NaN
# 1  Never seen such a deal for a punk since 2017! ...  NaN             NaN
# 2  Collection: ens \n Sold for: 1.0040189 Eth (12...  NaN             NaN
# 3  @Rocket_Moonshot @NzXrp @Bitboy_Crypto @digita...  NaN             NaN
# 4  @abu_crypto1 🩸 Scary bunny is a meme token wit...  NaN             NaN
#
#   geo.type                   id  quote_count        quoted_status.created_at  \
# 0      NaN  1591039006850310148            0                             NaN
# 1      NaN  1591039006770622468            0  Fri Nov 11 11:00:59 +0000 2022
# 2      NaN  1591039006501994503            0                             NaN
# 3      NaN  1591039007357550592            0                             NaN
# 4      NaN  1591039007764668417            0                             NaN
#
#    ... truncated  truncatedquoted_status.truncated  \
# 0  ...     False                               NaN
# 1  ...      True                               NaN
# 2  ...      True                               NaN
# 3  ...      True                               NaN
# 4  ...      True                               NaN
#
#                   user.created_at  user.followers_count  user.friends_count  \
# 0  Mon Jul 11 06:36:43 +0000 2011                  7050                5554
# 1  Wed Nov 09 14:09:46 +0000 2022                     0                   2
# 2  Sun May 01 15:06:34 +0000 2022                   106                   2
# 3  Wed Dec 18 21:46:55 +0000 2013                     0                   0
# 4  Tue Oct 25 03:46:04 +0000 2022                     3                  50
#
#    user.geo_enabled              user.id   user.location  \
# 0              True            333239871  CARBONdale, CO
# 1             False  1590345908172083201     Netherlands
# 2             False  1520781667769614337      blockchain
# 3             False           2252580014            None
# 4             False  1584753080113025025            None
#
#   quoted_status.geo.coordinates  quoted_status.geo.type
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                           NaN                     NaN
# 4                           NaN                     NaN
#
# [5 rows x 39 columns]

# %%
degrees = dict(G.degree())
degrees = sorted(degrees.items(), key=lambda x: x[1], reverse=True)
degrees = [degree for _, degree in degrees]

# %%
unique_degrees, degree_frequencies = np.unique(degrees, return_counts=True)
plt.bar(unique_degrees, degree_frequencies, color='blue', edgecolor='black')
plt.xscale('log')
plt.yscale('log')
plt.title('Node Degrees Histogram')
plt.xlabel('Degree')
plt.ylabel('Frequency')
plt.show()

# %%
degrees = dict(G.degree())
degrees_values = list(degrees.values())

# In-Degree
in_degrees = dict(G.in_degree())
in_degrees_values = list(in_degrees.values())

# Out-Degree
out_degrees = dict(G.out_degree())
out_degrees_values = list(out_degrees.values())

# Overall Degree Statistics
mean_degree = np.mean(degrees_values)
median_degree = np.median(degrees_values)
max_degree = np.max(degrees_values)
std_degree = np.std(degrees_values)

print("Overall Degree Statistics:")
print(f"Mean: {mean_degree}")
print(f"Median: {median_degree}")
print(f"Max: {max_degree}")
print(f"Standard Deviation: {std_degree}")

# In-Degree Statistics
mean_in_degree = np.mean(in_degrees_values)
median_in_degree = np.median(in_degrees_values)
max_in_degree = np.max(in_degrees_values)
std_in_degree = np.std(in_degrees_values)

print("\nIn-Degree Statistics:")
print(f"Mean: {mean_in_degree}")
print(f"Median: {median_in_degree}")
print(f"Max: {max_in_degree}")
print(f"Standard Deviation: {std_in_degree}")

# Out-Degree Statistics
mean_out_degree = np.mean(out_degrees_values)
median_out_degree = np.median(out_degrees_values)
max_out_degree = np.max(out_degrees_values)
std_out_degree = np.std(out_degrees_values)

print("\nOut-Degree Statistics:")
print(f"Mean: {mean_out_degree}")
print(f"Median: {median_out_degree}")
print(f"Max: {max_out_degree}")
print(f"Standard Deviation: {std_out_degree}")
# Out:
# Overall Degree Statistics:
# Mean: 3.0734418086012445
# Median: 1.0
# Max: 59825
# Standard Deviation: 144.90518822469494
#
# In-Degree Statistics:
# Mean: 1.5367209043006222
# Median: 1.0
# Max: 3736
# Standard Deviation: 6.068001288963873
#
# Out-Degree Statistics:
# Mean: 1.5367209043006222
# Median: 0.0
# Max: 59825
# Standard Deviation: 144.78788425976285

# %%
all_scc = list(nx.strongly_connected_components(G))
all_scc = sorted(all_scc, key=len, reverse=True)

# %%
scc_sizes = [len(scc) for scc in all_scc]
scc_sizes, scc_frequencies = np.unique(scc_sizes, return_counts=True)


# Plot the histogram with x-axis treated as categorical
plt.bar(range(len(scc_sizes)), scc_frequencies, color='blue')
plt.xticks(range(len(scc_sizes)), scc_sizes)
plt.yscale('log')
plt.title('Strongly Connected Components Histogram')
plt.xlabel('SCC Size (Number of Nodes)')
plt.ylabel('Frequency')
plt.show()

# %%
def visualize_scc(G, scc, show_labels = False):
    
    subgraph = G.subgraph(scc)

    pos = nx.kamada_kawai_layout(subgraph)
        
    nx.draw(
            subgraph,
            pos,
            node_color='skyblue',
            node_size=100,
            font_size=6,
            font_color='black',
            font_weight='bold',
            edge_color='gray',
            linewidths=1,
            alpha=0.7
        )
     
    if show_labels:
            
        label_pos = {k: (x, y - 0.12) for k, (x, y) in pos.items()}
        nx.draw_networkx_labels(subgraph, label_pos, font_size=6, font_color='black', font_weight='bold')

    
    plt.title('Connected Component Visualization')
    plt.show()

# %%
visualize_scc(G, all_scc[0])

# %%
all_scc[0]
# Out:
# {3840,
#  43763,
#  798536,
#  896141,
#  2030711,
#  2200781,
#  2723411,
#  3586271,
#  4004901,
#  4107711,
#  5022271,
#  5404442,
#  5686612,
#  5763262,
#  5867132,
#  6450372,
#  7184612,
#  7864222,
#  8467082,
#  8632762,
#  9026112,
#  9078472,
#  9571702,
#  9717472,
#  10446482,
#  11336782,
#  11471572,
#  11582012,
#  12071362,
#  12263542,
#  14095650,
#  14096763,
#  14101605,
#  14123881,
#  14182218,
#  14196108,
#  14285961,
#  14334846,
#  14379660,
#  14562285,
#  14592709,
#  14654085,
#  14723614,
#  14814762,
#  14855994,
#  14931637,
#  14935367,
#  15043917,
#  15226458,
#  15250501,
#  15281391,
#  15446531,
#  15567173,
#  15672273,
#  15809138,
#  15863880,
#  15950086,
#  15985111,
#  16076032,
#  16106584,
#  16598957,
#  16783996,
#  16861509,
#  17250666,
#  17351167,
#  17702451,
#  17881764,
#  17888010,
#  17925409,
#  18189286,
#  18213426,
#  18266688,
#  18269124,
#  18300968,
#  18359716,
#  18378349,
#  18555793,
#  18686907,
#  18719020,
#  18839937,
#  18856867,
#  18946913,
#  19062153,
#  19079480,
#  19224439,
#  19546277,
#  19721574,
#  19748227,
#  19951102,
#  20169416,
#  20178419,
#  20374262,
#  20648704,
#  20656604,
#  20844341,
#  20902138,
#  21526988,
#  21696279,
#  21822997,
#  22031726,
#  22396478,
#  22681084,
#  22758405,
#  23504313,
#  23564055,
#  24127811,
#  24277551,
#  25886242,
#  25913049,
#  26136365,
#  26377478,
#  26693708,
#  27557141,
#  27900790,
#  28212513,
#  28582680,
#  29034000,
#  30192824,
#  30325257,
#  30597171,
#  30699048,
#  30766919,
#  31701010,
#  32002507,
#  32201297,
#  33774289,
#  33939145,
#  34415961,
#  35101986,
#  35415440,
#  35486890,
#  35499699,
#  35749949,
#  36619953,
#  36691434,
#  38271276,
#  38472405,
#  39207995,
#  40742821,
#  42584365,
#  43362712,
#  43579221,
#  43775786,
#  43949721,
#  44505979,
#  45817623,
#  47003920,
#  47526275,
#  47966112,
#  48093881,
#  48351615,
#  48924841,
#  50703014,
#  50976550,
#  52247685,
#  52549030,
#  53113691,
#  53712478,
#  53836928,
#  54577897,
#  56562803,
#  57268394,
#  57394106,
#  58487473,
#  61417559,
#  66106683,
#  66533920,
#  66950686,
#  68739089,
#  68854969,
#  75209239,
#  75797367,
#  79714172,
#  84172182,
#  84490044,
#  90597181,
#  92281665,
#  93524235,
#  94274445,
#  95257097,
#  96568966,
#  97239626,
#  100416493,
#  101002059,
#  108438789,
#  111533746,
#  112509659,
#  112916339,
#  116232741,
#  116328126,
#  116835497,
#  117589511,
#  118917461,
#  119837703,
#  127831036,
#  130266161,
#  138141969,
#  141145166,
#  142537400,
#  146345384,
#  149571760,
#  150755250,
#  151535146,
#  151936663,
#  153962533,
#  154950529,
#  167518667,
#  169312819,
#  170049408,
#  171035372,
#  174981490,
#  176644153,
#  177906098,
#  180212381,
#  180493678,
#  183829477,
#  185157292,
#  188103539,
#  188369814,
#  189184866,
#  189518354,
#  194499127,
#  194658182,
#  196519120,
#  198700618,
#  211106542,
#  211530941,
#  212692308,
#  213032123,
#  213811226,
#  217534944,
#  219517617,
#  221519905,
#  223162829,
#  223238349,
#  223921570,
#  227682918,
#  229866044,
#  230186350,
#  230517800,
#  231208649,
#  233027426,
#  233034400,
#  239518063,
#  241493729,
#  242169927,
#  242763001,
#  246911146,
#  247973359,
#  249469940,
#  249768777,
#  251769222,
#  256053691,
#  257019844,
#  260767065,
#  270055938,
#  281877818,
#  283627388,
#  286432534,
#  286654612,
#  292565344,
#  295218901,
#  295299583,
#  297012999,
#  302505363,
#  312643305,
#  312789382,
#  313724502,
#  314864509,
#  323327362,
#  325111978,
#  349249475,
#  352441927,
#  357193782,
#  357786278,
#  358545917,
#  359671961,
#  363005534,
#  370872518,
#  375662595,
#  375707743,
#  380664281,
#  394531684,
#  399412477,
#  410080913,
#  412587524,
#  415794343,
#  419084104,
#  421271885,
#  437179266,
#  455937214,
#  465173917,
#  467535591,
#  476786738,
#  482418675,
#  487907633,
#  493351331,
#  497174361,
#  508996367,
#  516674802,
#  534493783,
#  565579525,
#  569827550,
#  583517629,
#  611986351,
#  739119366,
#  750750349,
#  757033212,
#  760853748,
#  776636857,
#  825713234,
#  848690137,
#  857391241,
#  865427900,
#  889273682,
#  948935767,
#  1021817359,
#  1135622396,
#  1177420700,
#  1187889182,
#  1194984822,
#  1203182527,
#  1225362522,
#  1244422231,
#  1290247555,
#  1361039118,
#  1376161898,
#  1386439608,
#  1431950773,
#  1460283925,
#  1463217036,
#  1469603575,
#  1478121462,
#  1527806202,
#  1530033576,
#  1530530365,
#  1566114613,
#  1615557272,
#  1643500784,
#  1649128015,
#  1688796138,
#  1694362759,
#  1881823231,
#  1932590653,
#  1961333743,
#  2159099744,
#  2178012643,
#  2188849260,
#  2190759643,
#  2193616844,
#  2206472570,
#  2215937899,
#  2259434528,
#  2285235781,
#  2288889440,
#  2320755170,
#  2353891049,
#  2361601055,
#  2362854624,
#  2372510178,
#  2373682811,
#  2402535456,
#  2434882878,
#  2437938810,
#  2453385626,
#  2474749586,
#  2478756618,
#  2488868005,
#  2539578409,
#  2561715571,
#  2565412998,
#  2573380344,
#  2590633042,
#  2593497397,
#  2611856134,
#  2730853586,
#  2743863562,
#  2799211554,
#  2839135427,
#  2930644399,
#  2933805082,
#  2966660663,
#  3005733012,
#  3012852462,
#  3015161303,
#  3105304911,
#  3161378401,
#  3216547243,
#  3226266525,
#  3229279664,
#  3238783482,
#  3260096383,
#  3309908860,
#  3313864528,
#  3364497995,
#  3696215239,
#  3740778132,
#  3765917302,
#  3793308794,
#  3833343869,
#  3833416227,
#  4011928402,
#  4119727762,
#  4135644558,
#  4182894076,
#  4315649778,
#  4711717992,
#  702654540387127296,
#  706950859599454208,
#  710463119886262272,
#  711196955582398464,
#  711905146230476800,
#  717488895928041472,
#  723730502927175680,
#  725253338640617472,
#  725969359089229824,
#  742735530287304704,
#  744660060635271168,
#  745295911085973504,
#  755438286110195712,
#  755731653910200320,
#  766352401771134976,
#  767122751110975488,
#  771255865273823232,
#  782946231551131648,
#  789205988259704832,
#  796056596229029888,
#  801191868969013248,
#  805160271388049408,
#  820252180796100608,
#  820282353436200960,
#  823766058909761536,
#  826309082772492288,
#  826856100494528512,
#  830711834848043008,
#  832890013759262720,
#  851583986270957568,
#  864393238123343872,
#  865835753867157504,
#  867382533876576256,
#  874312616671272960,
#  875054869995896832,
#  877728873340956672,
#  877807935493033984,
#  877903433117859840,
#  887748030304329728,
#  893818632089763840,
#  894317267273560064,
#  898760033994977280,
#  899151164473790464,
#  899400132176859136,
#  902839045356744704,
#  902926941413453824,
#  905078986656673792,
#  906870773066772480,
#  918804624303382528,
#  923853191799803904,
#  931615713558634496,
#  932312228614701056,
#  935723010744553472,
#  935742315389444096,
#  938606626017370112,
#  939131942775218176,
#  940853278652411904,
#  943506806931734528,
#  944001536866312192,
#  944686196331966464,
#  945521861168914432,
#  945817135816654848,
#  947673769694416896,
#  948974801737134080,
#  950915985422221312,
#  951920334831173632,
#  954005112174862336,
#  958118843636854784,
#  958367738338140160,
#  960949527279742976,
#  961026235122958336,
#  962958900906680320,
#  971361892735291392,
#  981208355115974656,
#  984453536254713856,
#  985688130509393920,
#  987343085251317760,
#  993673575230996480,
#  995678645762093056,
#  997502650357727232,
#  999492441513148416,
#  1007733777383247872,
#  1025967921472786432,
#  1031747223569227776,
#  1032339176858050560,
#  1037045241084342272,
#  1044207764212518912,
#  1044218542453854208,
#  1051852534518824960,
#  1052829861138509824,
#  1073132650309726208,
#  1079853966681346048,
#  1096870473252642816,
#  1106274235763314688,
#  1106959667702444032,
#  1118104888393650176,
#  1123403704323805184,
#  1128606567354359808,
#  1131352246573195264,
#  1136819035163619328,
#  1170347938868076544,
#  1175650198116347904,
#  1176293728170008576,
#  1196542741871771648,
#  1205909348557426688,
#  1218258049556594688,
#  1219719960693334016,
#  1232319080637616128,
#  1252627966724648960,
#  1259032968707952640,
#  1260559704335568896,
#  1265559881588899840,
#  1270906326823186432,
#  1281457267582177280,
#  1293955372424654848,
#  1297651178256257024,
#  1301215504686694400,
#  1305502637547192320,
#  1310446297812480000,
#  1323762343302615040,
#  1326211445978144768,
#  1327343239800582144,
#  1332026809181986816,
#  1339588489537486848,
#  1344759366671589376,
#  1348722865848332288,
#  1356386110847377408,
#  1386510948790202368,
#  1395485033155031040,
#  1401047579647954944,
#  1402397565425967104,
#  1405362161229119488,
#  1425531375751421952,
#  1433042511128416256,
#  1439692694880591872,
#  1446715714082115584,
#  1450882486372913152,
#  1451036242431262720,
#  1457997372055752704,
#  1470812043385049088,
#  1484117053892141056,
#  1492510878323081216,
#  1495917535354626048,
#  1496027288294592512,
#  1509533768759103488,
#  1527288227714899968,
#  1530667470947856384,
#  1542716844758355968,
#  1550192484721905664,
#  1574337751885156352,
#  1577494050906816512,
#  1578844681819099136,
#  1582468777270198272,
#  1590026842735403008,
#  1590027083350261760,
#  1590146886815580160,
#  1592499357336616960,
#  1592592299564957696}

# %%
df[df['user.id'] == 3586271]
# Out:
#                            created_at  \
# 94687  Fri Nov 11 12:40:14 +0000 2022
# 80438  Thu Nov 10 01:04:37 +0000 2022
# 40835  Wed Nov 09 23:33:25 +0000 2022
# 82149  Fri Nov 11 18:33:50 +0000 2022
# 3002   Mon Nov 14 14:36:49 +0000 2022
# 97596  Sat Nov 12 01:39:12 +0000 2022
# 66536  Mon Nov 14 02:13:31 +0000 2022
# 61355  Sat Nov 12 14:00:07 +0000 2022
# 86170  Sat Nov 12 02:59:31 +0000 2022
# 22525  Sun Nov 13 20:59:30 +0000 2022
# 7836   Thu Nov 17 14:29:00 +0000 2022
# 65269  Wed Nov 23 01:38:37 +0000 2022
# 94607  Wed Nov 23 02:08:48 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 94687  You may think that all centralized exchanges a...               0
# 80438  The thing that bothers me most about these col...               7
# 40835                                                NaN               0
# 82149                                                NaN               0
# 3002   It took a few bean bag chairs and billions of ...               0
# 97596  I have deep respect for principled people in c...               0
# 66536                                                NaN               0
# 61355  Stop this bullshit about custody of funds bein...               0
# 86170  One of the big reasons our business wasn’t abl...              13
# 22525  Only way to take your mind off one of the shit...               0
# 7836                                                 NaN               0
# 65269  It kind of feels weird that @binance is out he...               0
# 94607  If you think the only person finding shady way...               1
#
#                                                full_text  geo geo.coordinates  \
# 94687  You may think that all centralized exchanges a...  NaN             NaN
# 80438  The thing that bothers me most about these col...  NaN             NaN
# 40835  In a way @cobie he was trying to bankrupt thes...  NaN             NaN
# 82149  so long as i don't have to have a laborious bl...  NaN             NaN
# 3002   It took a few bean bag chairs and billions of ...  NaN             NaN
# 97596  I have deep respect for principled people in c...  NaN             NaN
# 66536  Somehow we’ve managed to allow Bitboy to escap...  NaN             NaN
# 61355  Stop this bullshit about custody of funds bein...  NaN             NaN
# 86170  One of the big reasons our business wasn’t abl...  NaN             NaN
# 22525  Only way to take your mind off one of the shit...  NaN             NaN
# 7836   Would love to get some details from those addi...  NaN             NaN
# 65269  It kind of feels weird that @binance is out he...  NaN             NaN
# 94607  If you think the only person finding shady way...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 94687      NaN  1591048152110755842            0
# 80438      NaN  1590510705132068864            0
# 40835      NaN  1590487755586678785            0
# 82149      NaN  1591137138678063104            0
# 3002       NaN  1592164656743075841            0
# 97596      NaN  1591244186186969088            0
# 66536      NaN  1591977599592730624            0
# 61355      NaN  1591430643501903872            0
# 86170      NaN  1591264400488689664            0
# 22525      NaN  1591898571208790016            0
# 7836       NaN  1593249851055435786            0
# 65269      NaN  1595230304276566018            0
# 94607      NaN  1595237902874812417            0
#
#              quoted_status.created_at  ... truncated  \
# 94687                             NaN  ...      True
# 80438                             NaN  ...      True
# 40835  Sat Nov 05 18:43:11 +0000 2022  ...     False
# 82149  Fri Nov 11 16:37:43 +0000 2022  ...     False
# 3002                              NaN  ...      True
# 97596                             NaN  ...      True
# 66536                             NaN  ...     False
# 61355                             NaN  ...      True
# 86170                             NaN  ...      True
# 22525                             NaN  ...      True
# 7836   Thu Nov 17 14:24:56 +0000 2022  ...     False
# 65269                             NaN  ...      True
# 94607                             NaN  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 94687                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 80438                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 40835                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 82149                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 3002                                NaN  Fri Apr 06 03:57:54 +0000 2007
# 97596                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 66536                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 61355                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 86170                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 22525                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 7836                                NaN  Fri Apr 06 03:57:54 +0000 2007
# 65269                               NaN  Fri Apr 06 03:57:54 +0000 2007
# 94607                               NaN  Fri Apr 06 03:57:54 +0000 2007
#
#        user.followers_count  user.friends_count  user.geo_enabled  user.id  \
# 94687                 26532                2695              True  3586271
# 80438                 26538                2695              True  3586271
# 40835                 26509                2692              True  3586271
# 82149                 26533                2697              True  3586271
# 3002                  26512                2699              True  3586271
# 97596                 26534                2696              True  3586271
# 66536                 26514                2699              True  3586271
# 61355                 26532                2697              True  3586271
# 86170                 26524                2699              True  3586271
# 22525                 26519                2699              True  3586271
# 7836                  26503                2700              True  3586271
# 65269                 26475                2699              True  3586271
# 94607                 26471                2710              True  3586271
#
#        user.location quoted_status.geo.coordinates  quoted_status.geo.type
# 94687  Virginia, USA                           NaN                     NaN
# 80438  Virginia, USA                           NaN                     NaN
# 40835  Virginia, USA                           NaN                     NaN
# 82149  Virginia, USA                           NaN                     NaN
# 3002   Virginia, USA                           NaN                     NaN
# 97596  Virginia, USA                           NaN                     NaN
# 66536  Virginia, USA                           NaN                     NaN
# 61355  Virginia, USA                           NaN                     NaN
# 86170  Virginia, USA                           NaN                     NaN
# 22525  Virginia, USA                           NaN                     NaN
# 7836   Virginia, USA                           NaN                     NaN
# 65269  Virginia, USA                           NaN                     NaN
# 94607  Virginia, USA                           NaN                     NaN
#
# [13 rows x 39 columns]

# %%
visualize_scc(G, all_scc[1])

# %%
all_scc[1]
# Out:
# {825202871427751936,
#  912957684852318208,
#  1510467423362637824,
#  1517168776977915904,
#  1517170926651166720,
#  1518663117966049280,
#  1518981680060461056,
#  1518983855730212864,
#  1518993327513047040,
#  1519152370491437056,
#  1520268892345577472,
#  1520269534434758656,
#  1520812629660372992,
#  1521694472479952896,
#  1522011986514440192,
#  1522506688842010624,
#  1522822906023088128,
#  1526593404473249792,
#  1548336466639884288,
#  1548680749213106176,
#  1549619001365790720,
#  1563756343370035200,
#  1563814773254660096,
#  1566883966656819200,
#  1574611704805150720}

# %%
df[df['user.id'] == 1518663117966049280]
# Out:
#                            created_at  \
# 9639   Thu Nov 10 09:24:06 +0000 2022
# 15702  Fri Nov 11 07:24:57 +0000 2022
# 16490  Fri Nov 11 07:21:52 +0000 2022
# 16757  Fri Nov 11 07:25:18 +0000 2022
# 16987  Fri Nov 11 07:25:03 +0000 2022
# ...                               ...
# 50286  Wed Nov 23 12:25:55 +0000 2022
# 50398  Wed Nov 23 12:31:16 +0000 2022
# 50495  Wed Nov 23 12:25:44 +0000 2022
# 51009  Wed Nov 23 12:26:07 +0000 2022
# 88216  Wed Nov 23 03:40:12 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 9639   @BrijSharma1980 @therahulads @CryptoAdsIndia @...               5
# 15702  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               2
# 16490  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               2
# 16757  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               2
# 16987  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               2
# ...                                                  ...             ...
# 50286  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               2
# 50398  #ADSCOIN is the Future of #Crypto World. Comin...              14
# 50495  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               6
# 51009  @BrijSharma1980 @therahulads @CryptoAdsIndia @...               2
# 88216  #ADSCOIN is the Future of #Crypto World. Comin...              49
#
#                                                full_text  geo geo.coordinates  \
# 9639   @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 15702  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 16490  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 16757  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 16987  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# ...                                                  ...  ...             ...
# 50286  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 50398  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 50495  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 51009  @BrijSharma1980 @therahulads @CryptoAdsIndia @...  NaN             NaN
# 88216  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 9639       NaN  1590636408221618176            1
# 15702      NaN  1590968807153373185            0
# 16490      NaN  1590968031781748736            0
# 16757      NaN  1590968895497990144            0
# 16987      NaN  1590968835183882240            0
# ...        ...                  ...          ...
# 50286      NaN  1595393205339828224            0
# 50398      NaN  1595394549391949834            0
# 50495      NaN  1595393158023909378            0
# 51009      NaN  1595393255126233088            0
# 88216      NaN  1595260902571651073            3
#
#              quoted_status.created_at  ... truncated  \
# 9639                              NaN  ...      True
# 15702                             NaN  ...      True
# 16490                             NaN  ...      True
# 16757                             NaN  ...      True
# 16987                             NaN  ...      True
# ...                               ...  ...       ...
# 50286                             NaN  ...      True
# 50398  Wed Nov 23 03:06:11 +0000 2022  ...      True
# 50495                             NaN  ...      True
# 51009                             NaN  ...      True
# 88216  Wed Nov 23 00:49:57 +0000 2022  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 9639                                NaN  Mon Apr 25 18:48:12 +0000 2022
# 15702                               NaN  Mon Apr 25 18:48:12 +0000 2022
# 16490                               NaN  Mon Apr 25 18:48:12 +0000 2022
# 16757                               NaN  Mon Apr 25 18:48:12 +0000 2022
# 16987                               NaN  Mon Apr 25 18:48:12 +0000 2022
# ...                                 ...                             ...
# 50286                               NaN  Mon Apr 25 18:48:12 +0000 2022
# 50398                               NaN  Mon Apr 25 18:48:12 +0000 2022
# 50495                               NaN  Mon Apr 25 18:48:12 +0000 2022
# 51009                               NaN  Mon Apr 25 18:48:12 +0000 2022
# 88216                               NaN  Mon Apr 25 18:48:12 +0000 2022
#
#        user.followers_count  user.friends_count  user.geo_enabled  \
# 9639                    346                  67             False
# 15702                   346                  67             False
# 16490                   346                  67             False
# 16757                   346                  67             False
# 16987                   346                  67             False
# ...                     ...                 ...               ...
# 50286                   382                  67             False
# 50398                   382                  67             False
# 50495                   382                  67             False
# 51009                   382                  67             False
# 88216                   382                  67             False
#
#                    user.id         user.location  \
# 9639   1518663117966049280  Muzaffarnagar, India
# 15702  1518663117966049280  Muzaffarnagar, India
# 16490  1518663117966049280  Muzaffarnagar, India
# 16757  1518663117966049280  Muzaffarnagar, India
# 16987  1518663117966049280  Muzaffarnagar, India
# ...                    ...                   ...
# 50286  1518663117966049280  Muzaffarnagar, India
# 50398  1518663117966049280  Muzaffarnagar, India
# 50495  1518663117966049280  Muzaffarnagar, India
# 51009  1518663117966049280  Muzaffarnagar, India
# 88216  1518663117966049280  Muzaffarnagar, India
#
#       quoted_status.geo.coordinates  quoted_status.geo.type
# 9639                            NaN                     NaN
# 15702                           NaN                     NaN
# 16490                           NaN                     NaN
# 16757                           NaN                     NaN
# 16987                           NaN                     NaN
# ...                             ...                     ...
# 50286                           NaN                     NaN
# 50398                           NaN                     NaN
# 50495                           NaN                     NaN
# 51009                           NaN                     NaN
# 88216                           NaN                     NaN
#
# [949 rows x 39 columns]

# %%
visualize_scc(G, all_scc[2])

# %%
all_scc[2]
# Out:
# {132146668,
#  302686882,
#  407861358,
#  1373794038,
#  2366663978,
#  2539284575,
#  2884498638,
#  3196973563,
#  3247613569,
#  3346348648,
#  4921730335,
#  706347814960259072,
#  876757408038572032,
#  950621345544482816,
#  1236599199103201280,
#  1536572639321661440,
#  1568207259628638208,
#  1578441484923199488,
#  1582049279023415296,
#  1588568332160012288,
#  1592585215859650560}

# %%
df[df['user.id'] == 950621345544482816]
# Out:
#                            created_at  \
# 807    Sun Nov 20 16:12:37 +0000 2022
# 33878  Sun Nov 20 16:10:06 +0000 2022
# 45047  Sun Nov 20 17:24:42 +0000 2022
# 57334  Sun Nov 20 16:11:08 +0000 2022
# 66984  Sun Nov 20 06:01:59 +0000 2022
# ...                               ...
# 92791  Wed Nov 23 13:07:28 +0000 2022
# 52196  Wed Nov 23 13:07:20 +0000 2022
# 20911  Wed Nov 23 14:39:24 +0000 2022
# 25579  Tue Nov 22 18:02:29 +0000 2022
# 31741  Tue Nov 22 08:35:20 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 807    #SaveKashmiriHindus PM Package Employee’s \nTi...               3
# 33878  #SaveKashmiriHindus PM Package Employee’s \nTi...               0
# 45047  #SaveKashmiriHindus PM Package Employee’s \nTi...               0
# 57334  #SaveKashmiriHindus PM Package Employee’s \nTi...               3
# 66984  #SaveKashmiriHindus PM Package Employee’s \nTi...               3
# ...                                                  ...             ...
# 92791  @BJP4JnK @ImRavinderRaina #SaveKashmiriHindus ...               2
# 52196  #SaveKashmiriHindus PM Package Employee’s \nTi...               1
# 20911  @ImRavinderRaina ji ap aage bhado, hum pm pack...               0
# 25579  #SaveKashmiriHindus PM Package Employee’s \nTi...               8
# 31741  #SaveKashmiriHindus PM Package Employee’s \nTi...               0
#
#                                                full_text  geo geo.coordinates  \
# 807    #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 33878  #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 45047  #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 57334  #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 66984  #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# ...                                                  ...  ...             ...
# 92791  @BJP4JnK @ImRavinderRaina #SaveKashmiriHindus ...  NaN             NaN
# 52196  #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 20911  @ImRavinderRaina ji ap aage bhado, hum pm pack...  NaN             NaN
# 25579  #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
# 31741  #SaveKashmiriHindus PM Package Employee’s \nTi...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 807        NaN  1594363093487755264            2
# 33878      NaN  1594362459166371840            0
# 45047      NaN  1594381230992404481            0
# 57334      NaN  1594362720010526721            2
# 66984      NaN  1594209420845932554            4
# ...        ...                  ...          ...
# 92791      NaN  1595403661433139200            1
# 52196      NaN  1595403627937599488            0
# 20911      NaN  1595426794366455809            0
# 25579      NaN  1595115515433082882            2
# 31741      NaN  1594972790020767744            0
#
#              quoted_status.created_at  ... truncated  \
# 807    Sun Nov 20 09:29:29 +0000 2022  ...      True
# 33878  Sat Nov 19 14:11:20 +0000 2022  ...      True
# 45047  Sat Nov 19 05:32:30 +0000 2022  ...      True
# 57334  Sun Nov 20 03:40:33 +0000 2022  ...      True
# 66984  Sun Nov 20 02:50:32 +0000 2022  ...      True
# ...                               ...  ...       ...
# 92791                             NaN  ...      True
# 52196  Wed Nov 23 12:04:59 +0000 2022  ...      True
# 20911  Tue Nov 22 15:32:47 +0000 2022  ...      True
# 25579  Tue Nov 22 15:27:06 +0000 2022  ...      True
# 31741  Mon Nov 21 18:40:35 +0000 2022  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 807                                 NaN  Tue Jan 09 06:52:45 +0000 2018
# 33878                               NaN  Tue Jan 09 06:52:45 +0000 2018
# 45047                               NaN  Tue Jan 09 06:52:45 +0000 2018
# 57334                               NaN  Tue Jan 09 06:52:45 +0000 2018
# 66984                               NaN  Tue Jan 09 06:52:45 +0000 2018
# ...                                 ...                             ...
# 92791                               NaN  Tue Jan 09 06:52:45 +0000 2018
# 52196                               NaN  Tue Jan 09 06:52:45 +0000 2018
# 20911                               NaN  Tue Jan 09 06:52:45 +0000 2018
# 25579                               NaN  Tue Jan 09 06:52:45 +0000 2018
# 31741                               NaN  Tue Jan 09 06:52:45 +0000 2018
#
#        user.followers_count  user.friends_count  user.geo_enabled  \
# 807                      70                 185             False
# 33878                    70                 185             False
# 45047                    70                 185             False
# 57334                    70                 185             False
# 66984                    70                 184             False
# ...                     ...                 ...               ...
# 92791                    69                 185             False
# 52196                    69                 185             False
# 20911                    69                 184             False
# 25579                    69                 183             False
# 31741                    69                 183             False
#
#                   user.id           user.location  \
# 807    950621345544482816  Jammu & Kashmir, India
# 33878  950621345544482816  Jammu & Kashmir, India
# 45047  950621345544482816  Jammu & Kashmir, India
# 57334  950621345544482816  Jammu & Kashmir, India
# 66984  950621345544482816  Jammu & Kashmir, India
# ...                   ...                     ...
# 92791  950621345544482816  Jammu & Kashmir, India
# 52196  950621345544482816  Jammu & Kashmir, India
# 20911  950621345544482816  Jammu & Kashmir, India
# 25579  950621345544482816  Jammu & Kashmir, India
# 31741  950621345544482816  Jammu & Kashmir, India
#
#       quoted_status.geo.coordinates  quoted_status.geo.type
# 807                             NaN                     NaN
# 33878                           NaN                     NaN
# 45047                           NaN                     NaN
# 57334                           NaN                     NaN
# 66984                           NaN                     NaN
# ...                             ...                     ...
# 92791                           NaN                     NaN
# 52196                           NaN                     NaN
# 20911                           NaN                     NaN
# 25579                           NaN                     NaN
# 31741                           NaN                     NaN
#
# [267 rows x 39 columns]

# %%
visualize_scc(G, all_scc[3])

# %%
all_scc[3]
# Out:
# {5533262,
#  6068692,
#  7910872,
#  25570572,
#  85636440,
#  372650546,
#  931179333607215104,
#  1051710088098996224,
#  1117689210566316032,
#  1314846469128585216,
#  1471733556989018112}

# %%
df[df['user.id'] == 5533262]
# Out:
#                            created_at  \
# 46262  Fri Nov 11 11:22:11 +0000 2022
# 49540  Fri Nov 11 07:55:40 +0000 2022
# 64434  Fri Nov 11 06:39:55 +0000 2022
# 28478  Wed Nov 09 21:24:51 +0000 2022
# 92692  Wed Nov 09 19:29:23 +0000 2022
# ...                               ...
# 32471  Tue Nov 22 08:30:53 +0000 2022
# 17273  Tue Nov 22 05:06:53 +0000 2022
# 39397  Wed Nov 23 12:22:59 +0000 2022
# 65515  Wed Nov 23 14:03:12 +0000 2022
# 81217  Wed Nov 23 12:01:53 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 46262  @TravellerNow @sedane94 @binance can, but woul...               0
# 49540                                                NaN               6
# 64434                                                NaN               0
# 28478  @danhwang88 Improve cosmos by distributing inf...               0
# 92692                                                NaN               0
# ...                                                  ...             ...
# 32471  This is incredibly good information on decentr...               0
# 17273  our team missed an osmosis upgrade.\n\nas a va...               0
# 39397                                                NaN               5
# 65515  I think more validators should be working on t...               2
# 81217  Stake with @notionaldao for some tech and stak...              20
#
#                                                full_text  geo geo.coordinates  \
# 46262  @TravellerNow @sedane94 @binance can, but woul...  NaN             NaN
# 49540              Noticing good stuff from cosmos news.  NaN             NaN
# 64434  Install the electric fence around cosmos and I...  NaN             NaN
# 28478  @danhwang88 Improve cosmos by distributing inf...  NaN             NaN
# 92692  this was posted in the cosmos hub public chat....  NaN             NaN
# ...                                                  ...  ...             ...
# 32471  This is incredibly good information on decentr...  NaN             NaN
# 17273  our team missed an osmosis upgrade.\n\nas a va...  NaN             NaN
# 39397  The Cosmos Hub community is unique in that you...  NaN             NaN
# 65515  I think more validators should be working on t...  NaN             NaN
# 81217  Stake with @notionaldao for some tech and stak...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 46262      NaN  1591028509195251712            0
# 49540      NaN  1590976539151433728            0
# 64434      NaN  1590957477574905857            0
# 28478      NaN  1590455400306192385            0
# 92692      NaN  1590426342696574977            0
# ...        ...                  ...          ...
# 32471      NaN  1594971667167850498            0
# 17273      NaN  1594920329285365763            0
# 39397      NaN  1595392466139897862            0
# 65515      NaN  1595417684425920512            0
# 81217      NaN  1595387157807788032            0
#
#              quoted_status.created_at  ... truncated  \
# 46262                             NaN  ...      True
# 49540  Thu Nov 10 20:08:07 +0000 2022  ...     False
# 64434                             NaN  ...     False
# 28478  Wed Nov 09 19:25:14 +0000 2022  ...      True
# 92692                             NaN  ...     False
# ...                               ...  ...       ...
# 32471  Tue Nov 22 06:04:14 +0000 2022  ...      True
# 17273                             NaN  ...      True
# 39397                             NaN  ...     False
# 65515                             NaN  ...      True
# 81217  Wed Nov 23 10:15:18 +0000 2022  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 46262                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 49540                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 64434                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 28478                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 92692                               NaN  Thu Apr 26 17:04:58 +0000 2007
# ...                                 ...                             ...
# 32471                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 17273                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 39397                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 65515                               NaN  Thu Apr 26 17:04:58 +0000 2007
# 81217                               NaN  Thu Apr 26 17:04:58 +0000 2007
#
#        user.followers_count  user.friends_count  user.geo_enabled  user.id  \
# 46262                 11697                5479              True  5533262
# 49540                 11697                5479              True  5533262
# 64434                 11701                5479              True  5533262
# 28478                 11699                5461              True  5533262
# 92692                 11701                5461              True  5533262
# ...                     ...                 ...               ...      ...
# 32471                 12063                5515              True  5533262
# 17273                 12059                5514              True  5533262
# 39397                 12024                5519              True  5533262
# 65515                 12048                5519              True  5533262
# 81217                 12023                5518              True  5533262
#
#         user.location quoted_status.geo.coordinates  quoted_status.geo.type
# 46262  Hanoi, Vietnam                           NaN                     NaN
# 49540  Hanoi, Vietnam                           NaN                     NaN
# 64434  Hanoi, Vietnam                           NaN                     NaN
# 28478  Hanoi, Vietnam                           NaN                     NaN
# 92692  Hanoi, Vietnam                           NaN                     NaN
# ...               ...                           ...                     ...
# 32471  Hanoi, Vietnam                           NaN                     NaN
# 17273  Hanoi, Vietnam                           NaN                     NaN
# 39397  Hanoi, Vietnam                           NaN                     NaN
# 65515  Hanoi, Vietnam                           NaN                     NaN
# 81217  Hanoi, Vietnam                           NaN                     NaN
#
# [242 rows x 39 columns]

# %%
all_scc[4]
# Out:
# {1153658704782397440,
#  1413674305636950016,
#  1480208511342571520,
#  1565046338915815424,
#  1585791768808681472,
#  1588364611191029760,
#  1589535471792574464}

# %%
df[df['user.id'] == 1589535471792574464]
# Out:
#                            created_at  \
# 49115  Sat Nov 12 09:20:26 +0000 2022
# 55709  Sat Nov 12 09:32:30 +0000 2022
# 78336  Sat Nov 12 01:11:39 +0000 2022
# 17611  Thu Nov 17 06:46:51 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 49115                                                NaN               0
# 55709                                                NaN               0
# 78336                                                NaN               0
# 17611  "I've got a lot of names, actually. But hey, t...               0
#
#                                                full_text  geo geo.coordinates  \
# 49115  "Not just any, "dog" a... \n\nDrum roll please...  NaN             NaN
# 55709  combat settings installed. But once it does an...  NaN             NaN
# 78336  I think I'm a pretty bad guy myself but even I...  NaN             NaN
# 17611  "I've got a lot of names, actually. But hey, t...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 49115      NaN  1591360258043424769            0
# 55709      NaN  1591363297068322816            0
# 78336      NaN  1591237254441472000            0
# 17611      NaN  1593133548982407168            0
#
#              quoted_status.created_at  ... truncated  \
# 49115  Sat Nov 12 09:18:42 +0000 2022  ...     False
# 55709                             NaN  ...     False
# 78336  Sat Nov 12 01:10:36 +0000 2022  ...     False
# 17611  Thu Nov 17 06:27:51 +0000 2022  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 49115                               NaN  Mon Nov 07 08:29:38 +0000 2022
# 55709                               NaN  Mon Nov 07 08:29:38 +0000 2022
# 78336                               NaN  Mon Nov 07 08:29:38 +0000 2022
# 17611                               NaN  Mon Nov 07 08:29:38 +0000 2022
#
#        user.followers_count  user.friends_count  user.geo_enabled  \
# 49115                   118                 201             False
# 55709                   118                 201             False
# 78336                   116                 196             False
# 17611                   149                 236             False
#
#                    user.id  user.location quoted_status.geo.coordinates  \
# 49115  1589535471792574464     Night City                           NaN
# 55709  1589535471792574464     Night City                           NaN
# 78336  1589535471792574464     Night City                           NaN
# 17611  1589535471792574464     Night City                           NaN
#
#        quoted_status.geo.type
# 49115                     NaN
# 55709                     NaN
# 78336                     NaN
# 17611                     NaN
#
# [4 rows x 39 columns]

# %%
curr_scc = all_scc[0]
start_node = list(curr_scc)[0]

reachable_nodes = nx.single_source_shortest_path_length(G, start_node)
non_scc_reachable_nodes = {node: distance for node, distance in reachable_nodes.items() if node not in curr_scc}
sorted_reachable_nodes = sorted(non_scc_reachable_nodes.items(), key=lambda x: x[1], reverse=True)

print(len(sorted_reachable_nodes)),
print(sorted_reachable_nodes[0:10])
# Out:
# 60245
# [(1525370781743558656, 15), (1525382365434253312, 15), (1553801954874331139, 15), (1522919316953260032, 15), (1583869360392773633, 15), (1489896283116503047, 15), (1030459668, 15), (1586175440905211905, 15), (1585103627173056512, 15), (1507962802979618825, 15)]

# %%
curr_scc = all_scc[1]
start_node = list(curr_scc)[0]

reachable_nodes = nx.single_source_shortest_path_length(G, start_node)
non_scc_reachable_nodes = {node: distance for node, distance in reachable_nodes.items() if node not in curr_scc}
sorted_reachable_nodes = sorted(non_scc_reachable_nodes.items(), key=lambda x: x[1], reverse=True)

print(len(sorted_reachable_nodes)),
print(sorted_reachable_nodes[0:10])
# Out:
# 105
# [(1568759581802909702, 3), (1571734799404105729, 3), (1573975927008083968, 3), (1542445423541067779, 3), (1319198305612566530, 3), (1217686721078259713, 3), (1560059622895267840, 3), (1567479414350397444, 3), (1518840321597075457, 2), (1571002006080462848, 2)]

# %%
df[df['user.id'] == 1571002006080462848]
# Out:
#                            created_at  \
# 15375  Fri Nov 11 08:35:16 +0000 2022
# 16015  Fri Nov 11 08:38:47 +0000 2022
# 16331  Fri Nov 11 08:39:39 +0000 2022
# 96343  Wed Nov 09 07:28:32 +0000 2022
# 96634  Wed Nov 09 07:24:17 +0000 2022
# ...                               ...
# 26571  Tue Nov 22 11:27:04 +0000 2022
# 70598  Tue Nov 22 03:21:51 +0000 2022
# 70633  Tue Nov 22 03:22:56 +0000 2022
# 72167  Tue Nov 22 07:46:27 +0000 2022
# 8987   Wed Nov 23 06:59:38 +0000 2022
#
#                                 extended_tweet.full_text  favorite_count  \
# 15375  #ADSCOIN is the Future of #Crypto World. Comin...               1
# 16015  #ADSCOIN is the Future of #Crypto World. Comin...               1
# 16331  #ADSCOIN is the Future of #Crypto World. Comin...               0
# 96343  @NathuniSingh12 @therahulads @BrijSharma1980 @...               3
# 96634  @NathuniSingh12 @therahulads @BrijSharma1980 @...               3
# ...                                                  ...             ...
# 26571  #ADSCOIN is the Future of #Crypto World. Comin...               1
# 70598  #ADSCOIN is the Future of #Crypto World. Comin...               1
# 70633  #ADSCOIN is the Future of #Crypto World. Comin...               1
# 72167  #ADSCOIN is the Future of #Crypto World. Comin...               1
# 8987   @BrijSharma1980 @WhaleChart "ADS GROUP OF COMP...               1
#
#                                                full_text  geo geo.coordinates  \
# 15375  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 16015  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 16331  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 96343  @NathuniSingh12 @therahulads @BrijSharma1980 @...  NaN             NaN
# 96634  @NathuniSingh12 @therahulads @BrijSharma1980 @...  NaN             NaN
# ...                                                  ...  ...             ...
# 26571  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 70598  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 70633  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 72167  #ADSCOIN is the Future of #Crypto World. Comin...  NaN             NaN
# 8987   @BrijSharma1980 @WhaleChart "ADS GROUP OF COMP...  NaN             NaN
#
#       geo.type                   id  quote_count  \
# 15375      NaN  1590986504297648130            0
# 16015      NaN  1590987390914813953            0
# 16331      NaN  1590987607827427330            0
# 96343      NaN  1590244933981855746            0
# 96634      NaN  1590243864065236992            0
# ...        ...                  ...          ...
# 26571      NaN  1595016006216605696            0
# 70598      NaN  1594893898958397440            0
# 70633      NaN  1594894168102694913            0
# 72167      NaN  1594960488211034112            0
# 8987       NaN  1595311092737011712            0
#
#              quoted_status.created_at  ... truncated  \
# 15375  Thu Nov 10 09:31:41 +0000 2022  ...      True
# 16015  Thu Nov 10 05:58:11 +0000 2022  ...      True
# 16331  Thu Nov 10 09:24:26 +0000 2022  ...      True
# 96343                             NaN  ...      True
# 96634                             NaN  ...      True
# ...                               ...  ...       ...
# 26571  Mon Nov 21 20:02:17 +0000 2022  ...      True
# 70598  Tue Nov 22 00:42:20 +0000 2022  ...      True
# 70633  Tue Nov 22 00:35:35 +0000 2022  ...      True
# 72167  Tue Nov 22 00:34:47 +0000 2022  ...      True
# 8987                              NaN  ...      True
#
#        truncatedquoted_status.truncated                 user.created_at  \
# 15375                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 16015                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 16331                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 96343                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 96634                               NaN  Sat Sep 17 05:07:10 +0000 2022
# ...                                 ...                             ...
# 26571                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 70598                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 70633                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 72167                               NaN  Sat Sep 17 05:07:10 +0000 2022
# 8987                                NaN  Sat Sep 17 05:07:10 +0000 2022
#
#        user.followers_count  user.friends_count  user.geo_enabled  \
# 15375                    19                  27              True
# 16015                    19                  27              True
# 16331                    19                  27              True
# 96343                    19                  27              True
# 96634                    19                  27              True
# ...                     ...                 ...               ...
# 26571                    17                  19              True
# 70598                    17                  19              True
# 70633                    17                  19              True
# 72167                    17                  19              True
# 8987                     17                  18              True
#
#                    user.id  user.location quoted_status.geo.coordinates  \
# 15375  1571002006080462848           None                          None
# 16015  1571002006080462848           None                          None
# 16331  1571002006080462848           None                          None
# 96343  1571002006080462848           None                          None
# 96634  1571002006080462848           None                          None
# ...                    ...            ...                           ...
# 26571  1571002006080462848           None                          None
# 70598  1571002006080462848           None                          None
# 70633  1571002006080462848           None                          None
# 72167  1571002006080462848           None                          None
# 8987   1571002006080462848           None                          None
#
#        quoted_status.geo.type
# 15375                    None
# 16015                    None
# 16331                    None
# 96343                    None
# 96634                    None
# ...                       ...
# 26571                    None
# 70598                    None
# 70633                    None
# 72167                    None
# 8987                     None
#
# [335 rows x 39 columns]

# %%
curr_scc = all_scc[2]
start_node = list(curr_scc)[0]

reachable_nodes = nx.single_source_shortest_path_length(G, start_node)
non_scc_reachable_nodes = {node: distance for node, distance in reachable_nodes.items() if node not in curr_scc}
sorted_reachable_nodes = sorted(non_scc_reachable_nodes.items(), key=lambda x: x[1], reverse=True)

print(len(sorted_reachable_nodes)),
print(sorted_reachable_nodes[0:10])
# Out:
# 28
# [(1591072188295258114, 6), (1520176072985247745, 5), (1176898458588012544, 5), (1310692223877623808, 5), (1514489571542994947, 4), (1591658154449829890, 4), (1593328244140433408, 4), (1487669652201218055, 3), (1568530209770737664, 3), (1237400987762962433, 3)]

# %%
import re
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
from wordcloud import WordCloud
from sklearn.cluster import KMeans


def clean_text(text):
    stop_words = set(stopwords.words('english'))
    custom_stopwords = set(['amp', 'rt', 'via', '...', '...', '’', '—', '“', '”', '‘', '’', '...', '``', "''", '️', '...'])
    text = text.lower()
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'[@#]', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    words = text.split()
    filtered_words = [word for word in words if word not in stop_words and word not in custom_stopwords]
    cleaned_text = ' '.join(filtered_words)
    return cleaned_text

def get_tfidf(df, scc):
    nltk.download('stopwords')
    
    user_ids_in_scc = [node for node in scc]
    full_texts_in_scc = list(df[df['user.id'].isin(user_ids_in_scc)]['full_text'])
    cleaned_texts = [clean_text(text) for text in full_texts_in_scc]
    
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(cleaned_texts)
    feature_names = vectorizer.get_feature_names_out()

    return tfidf_matrix, feature_names


def get_top_k_words_from_scc(df, scc, k=50, barplot=False, wordcloud=True):

    tfidf_matrix, feature_names = get_tfidf(df, scc)
    term_sum = tfidf_matrix.sum(axis=0)
    term_df = pd.DataFrame({'term': feature_names, 'tfidf_sum': term_sum.tolist()[0]})
    term_df_sorted = term_df.sort_values(by='tfidf_sum', ascending=False)
    top_keywords = term_df_sorted.head(k)['term'].tolist()

    if(barplot):
        plt.figure(figsize=(12, 6))
        plt.bar(top_keywords, term_df_sorted.head(k)['tfidf_sum'], color='skyblue')
        plt.xticks(rotation=90, ha='right')
        plt.xlabel('Keywords')
        plt.ylabel('TF-IDF Sum')
        plt.title('Top' + str(k) + ' Keywords by TF-IDF Sum')
        plt.tight_layout()
        plt.show()
    
    if(wordcloud):
        
        wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(term_df_sorted.set_index('term')['tfidf_sum'][0:k].to_dict())
    
        plt.figure(figsize=(10, 5))
        plt.title('Top' + str(k) + ' Keywords by TF-IDF Sum')
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis('off')
        plt.show()
    
    return top_keywords

# %%
top_keywpords = get_top_k_words_from_scc(df, all_scc[0], k=50, barplot=False, wordcloud=True)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mridul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
top_keywpords = get_top_k_words_from_scc(df, all_scc[1], k=50, barplot=False, wordcloud=True)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/mridul/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
original_engagement = df[['favorite_count', 'retweet_count']].loc[df['quoted_status.id'].isnull()]
quoted_engagement = df[['quoted_status.favorite_count', 'quoted_status.retweet_count']].dropna()

avg_original_favorite = original_engagement['favorite_count'].mean()
avg_original_retweet = original_engagement['retweet_count'].mean()
avg_quoted_favorite = quoted_engagement['quoted_status.favorite_count'].mean()
avg_quoted_retweet = quoted_engagement['quoted_status.retweet_count'].mean()

print(f"Average favorites for original tweets: {avg_quoted_favorite:.2f}")
print(f"Average favorites for quotes: {avg_original_favorite:.2f}")
print("")
print(f"Average retweets for original tweets: {avg_quoted_retweet:.2f}")
print(f"Average retweets for quotes: {avg_original_retweet:.2f}")
# Out:
# Average favorites for original tweets: 2145.37
# Average favorites for quotes: 4.89
#
# Average retweets for original tweets: 502.87
# Average retweets for quotes: 1.48

# %%
df_network = df[['created_at', 'user.id', 'quoted_status.user.id']].copy()
df_network['created_at'] = pd.to_datetime(df_network['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')
df_network.sort_values(by='created_at', inplace=True)

# %%
def get_friends_followers_stat(scc, plot_title):
    # Extract friends and followers counts for users in all_scc[0]
    scc_users = df[df['user.id'].isin(scc) | df['quoted_status.user.id'].isin(scc)]
    scc_friends_followers = scc_users[['user.friends_count', 'user.followers_count']]

    start_node = list(scc)[0]

    reachable_nodes = nx.single_source_shortest_path_length(G, start_node)
    non_scc_reachable_nodes = {node: distance for node, distance in reachable_nodes.items() if node not in curr_scc}
    
    reachable_users = df[df['user.id'].isin(non_scc_reachable_nodes) | df['quoted_status.user.id'].isin(non_scc_reachable_nodes)]
    reachable_friends_followers = reachable_users[['user.friends_count', 'user.followers_count']]
    
    scc_stats = {
        'Mean Friends': round(np.mean(scc_friends_followers['user.friends_count'])),
        'Median Friends': round(np.median(scc_friends_followers['user.friends_count'])),
        'Mean Followers': round(np.mean(scc_friends_followers['user.followers_count'])),
        'Median Followers': round(np.median(scc_friends_followers['user.followers_count']))
    }
    
    reachable_stats = {
        'Mean Friends': round(np.mean(reachable_friends_followers['user.friends_count'])),
        'Median Friends': round(np.median(reachable_friends_followers['user.friends_count'])),
        'Mean Followers': round(np.mean(reachable_friends_followers['user.followers_count'])),
        'Median Followers': round(np.median(reachable_friends_followers['user.followers_count']))
    }

    
    labels = list(scc_stats.keys())
    scc_values = list(scc_stats.values())
    reachable_values = list(reachable_stats.values())
    
    bar_width = 0.35
    index = np.arange(len(labels))

    plt.rc('font', size=18)
    plt.rc('xtick', labelsize=18)
    plt.rc('ytick', labelsize=18)
    
    fig, ax = plt.subplots(figsize=(14, 9))
    
    bar1 = ax.bar(index, scc_values, bar_width, label='Within SCC', color='tab:blue')
    bar2 = ax.bar(index + bar_width, reachable_values, bar_width, label='Reachable from SCC', color='tab:orange')
    
    # ax.set_xlabel('Metrics')
    ax.set_ylabel('Counts')
    ax.set_title(plot_title, fontsize=20)
    ax.set_xticks(index + bar_width / 2)
    ax.set_xticklabels(labels)
    ax.legend()
    
    for bar, value in zip(bar1 + bar2, scc_values + reachable_values):
        height = bar.get_height()
        ax.text(bar.get_x() + bar.get_width() / 2, height, f'{value:.2f}', ha='center', va='bottom')
        
    plt.savefig("figures/"+plot_title.replace(" ", "_").lower()+"_fnf_stat.pdf", format="pdf", bbox_inches='tight')

    plt.show()

# %%
get_friends_followers_stat(all_scc[0], "SCC 1")

# %%
get_friends_followers_stat(all_scc[1], "SCC 2")

# %%
get_friends_followers_stat(all_scc[2], "SCC 3")

# %%
get_friends_followers_stat(all_scc[3], "SCC 4")

# %%
get_friends_followers_stat(all_scc[4], "SCC 5")

# %%
get_friends_followers_stat(all_scc[5], "SCC 6")

# %%
def plot_user_activity_evolution(selected_scc, plot_title):

    df_network_scc = df_network[df_network['user.id'].isin(selected_scc) | df_network['quoted_status.user.id'].isin(selected_scc)]
    df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')
    
    relevant_timestamps = df_network_scc[df_network_scc['user.id'].isin(selected_scc)]['created_at'].unique()
    relevant_timestamps = relevant_timestamps[relevant_timestamps >= pd.Timestamp('2022-11-09')]
    
    instances = []
    
    for timestamp in relevant_timestamps:
        instances.append(np.searchsorted(df_network_scc['created_at'], timestamp, side='right'))
        
    fig, ax1 = plt.subplots(figsize=(10, 6))
    
    color = 'tab:blue'
    ax1.set_title(plot_title, fontsize=16)
    ax1.set_xlabel('Timestamp')
    ax1.set_ylabel('Cumulative Number of Instances')
    ax1.plot(relevant_timestamps, instances, marker='o', markersize=3, linewidth=0.5, color=color)
    ax1.tick_params(axis='y', labelcolor=color)
    
    fig.tight_layout()
        
    plt.savefig("figures/"+plot_title.replace(" ", "_").lower()+"_evolution.pdf", format="pdf", bbox_inches='tight')

    plt.show()

# %%
plot_user_activity_evolution(all_scc[0], "SCC 1")
# Out:
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2369296087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

# %%
plot_user_activity_evolution(all_scc[1], "SCC 2")
# Out:
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2369296087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

# %%
plot_user_activity_evolution(all_scc[2], "SCC 3")
# Out:
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2369296087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

# %%
plot_user_activity_evolution(all_scc[3], "SCC 4")
# Out:
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2369296087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

# %%
plot_user_activity_evolution(all_scc[4], "SCC 5")
# Out:
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2369296087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

# %%
plot_user_activity_evolution(all_scc[5], "SCC 6")
# Out:
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2369296087.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

# %%
import matplotlib.patches as mpatches

selected_scc = all_scc[0]
df_network_scc = df_network[df_network['user.id'].isin(selected_scc) | df_network['quoted_status.user.id'].isin(selected_scc)]
df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

relevant_timestamps1 = df_network_scc[df_network_scc['user.id'].isin(selected_scc)]['created_at'].unique()
relevant_timestamps1 = relevant_timestamps1[relevant_timestamps1 >= pd.Timestamp('2022-11-09')]

instances1 = []

for timestamp in relevant_timestamps:
    instances1.append(np.searchsorted(df_network_scc['created_at'], timestamp, side='right'))
    

selected_scc = all_scc[1]
df_network_scc = df_network[df_network['user.id'].isin(selected_scc) | df_network['quoted_status.user.id'].isin(selected_scc)]
df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

relevant_timestamps2 = df_network_scc[df_network_scc['user.id'].isin(selected_scc)]['created_at'].unique()
relevant_timestamps2 = relevant_timestamps2[relevant_timestamps2 >= pd.Timestamp('2022-11-09')]

instances2 = []

for timestamp in relevant_timestamps2:
    instances2.append(np.searchsorted(df_network_scc['created_at'], timestamp, side='right'))


selected_scc = all_scc[2]
df_network_scc = df_network[df_network['user.id'].isin(selected_scc) | df_network['quoted_status.user.id'].isin(selected_scc)]
df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

relevant_timestamps3 = df_network_scc[df_network_scc['user.id'].isin(selected_scc)]['created_at'].unique()
relevant_timestamps3 = relevant_timestamps3[relevant_timestamps3 >= pd.Timestamp('2022-11-09')]

instances3 = []

for timestamp in relevant_timestamps3:
    instances3.append(np.searchsorted(df_network_scc['created_at'], timestamp, side='right'))


selected_scc = all_scc[3]
df_network_scc = df_network[df_network['user.id'].isin(selected_scc) | df_network['quoted_status.user.id'].isin(selected_scc)]
df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')

relevant_timestamps4 = df_network_scc[df_network_scc['user.id'].isin(selected_scc)]['created_at'].unique()
relevant_timestamps4 = relevant_timestamps4[relevant_timestamps4 >= pd.Timestamp('2022-11-09')]

instances4 = []

for timestamp in relevant_timestamps4:
    instances4.append(np.searchsorted(df_network_scc['created_at'], timestamp, side='right'))



fig, ax1 = plt.subplots(figsize=(10, 6))

plt.rc('font', size=15)
# plt.rc('axes', labelsize=15)
plt.rc('xtick', labelsize=11)
plt.rc('ytick', labelsize=14)

color1 = 'tab:blue'
color2 = 'tab:red'
color3 = 'tab:green'
color4 = 'tab:purple'

# ax1.set_title("Evolution of Instances for Different SCCs", fontsize=16)
ax1.set_xlabel('Timestamp')
ax1.spines['left'].set_position(('outward', 0))
ax1.spines['left'].set_color(color1)
ax1.plot(relevant_timestamps1, instances1, marker='o', markersize=3, linewidth=0.5, color=color1)
ax1.tick_params(axis='y', labelcolor=color1)


ax2 = ax1.twinx()
ax2.spines['left'].set_position(('outward', 60))
ax2.spines['left'].set_color(color2)
ax2.set_ylabel('Cumulative Number of Instances', color = 'black')
ax2.yaxis.tick_left()
ax2.yaxis.set_label_position('left')
ax2.tick_params(axis='y', colors=color2)
ax2.plot(relevant_timestamps2, instances2, marker='o', markersize=3, linewidth=0.5, color=color2)

ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 0))
ax3.spines['right'].set_color(color3)
ax3.yaxis.tick_right()
ax3.yaxis.set_label_position('right')
ax3.tick_params(axis='y', colors=color3)
ax3.plot(relevant_timestamps3, instances3, marker='o', markersize=3, linewidth=0.5, color=color3)

ax4 = ax1.twinx()
ax4.spines['right'].set_position(('outward', 60))
ax4.spines['right'].set_color(color4)
ax4.yaxis.tick_right()
ax4.yaxis.set_label_position('right')
ax4.tick_params(axis='y', colors=color4)
ax4.plot(relevant_timestamps4, instances4, marker='o', markersize=3, linewidth=0.5, color=color4)


patch1 = mpatches.Patch(color=color1, label='SCC 1')
patch2 = mpatches.Patch(color=color2, label='SCC 2')
patch3 = mpatches.Patch(color=color3, label='SCC 3')
patch4 = mpatches.Patch(color=color4, label='SCC 4')

plt.legend(handles=[patch1, patch2, patch3, patch4])

plt.savefig("figures/user_quote_scc_evolution.pdf", format="pdf", bbox_inches='tight')

plt.show()
# Out:
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2096875061.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2096875061.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2096875061.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')
# /var/folders/mr/lkxzqtl162nc8t8yqxl8hjyh0000gn/T/ipykernel_26607/2096875061.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_network_scc['created_at'] = pd.to_datetime(df_network_scc['created_at'], format='%a %b %d %H:%M:%S +0000 %Y')
