# %%
from steem import Steem
import pandas as pd


stm = Steem(nodes=['https://api.steemit.com'])

# %%
import pandas as pd

query = {
        "limit":100, #number of posts
        "tag":"" #tag of posts
        }
        
d = stm.get_discussions_by_created(query)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1c50441065c6> in <module>
#       6         }
#       7
# ----> 8 d = stm.get_discussions_by_created(query)
#
# NameError: name 'stm' is not defined

# %%
dd = pd.read_csv('steemit-data.csv')

dd.shape
# Out:
# (4030, 29)

# %%
dd.sort_values('created')
# Out:
#        post_id       author  \
# 99   101715302    boss-indo
# 98   101715306       bishwa
# 97   101715311        bitai
# 96   101715321        bio92
# 95   101715328      gerizim
# ..         ...          ...
# 523  101717817   morpheussa
# 522  101717818     krakonos
# 623  101717825  icon-monday
# 622  101717826      sarkari
# 621  101717827   mayorfaruk
#
#                                               permlink     category  \
# 99                      6qrlf6-alam-sekitar-or-klip-41  hive-132554
# 98                  any-body-want-free-nft-legit-onely          nft
# 97                                               uf6u9  hive-101145
# 96                                               237-4           kr
# 95                                         ge1la8cmfg3  hive-138667
# ..                                                 ...          ...
# 523  quick-stats-steem-kids-and-parents-active-post...  hive-139765
# 522               actifit-krakonos-20221108t194613785z  hive-193552
# 623                          an-anatomy-of-crypto-coin  hive-183397
# 622               body-or-brain-what-is-it-to-be-human         life
# 621         smudge-painting-of-a-lady-with-blonde-hair          art
#
#                                                  title  \
# 99                              Alam Sekitar | Klip 42
# 98                  Any body want free nft legit onely
# 97                                         가족 모두 격리 해제
# 96   237.  존 템플의 가치 투자 전략 4 (로렌 템플턴, 스콧 필립스 '존 템플턴의...
# 95                                              잠언 22장
# ..                                                 ...
# 523  Quick Stats - Steem Kids & Parents - Active Po...
# 522            My Actifit Report Card: November 8 2022
# 623                          An Anatomy of crypto coin
# 622            Body Or Brain - What is it to Be Human?
# 621         SMUDGE PAINTING OF A LADY WITH BLONDE HAIR
#
#                                                   body  \
# 99   <center>https://cdn.steemitimages.com/DQmYk1pJ...
# 98   ![8-zjQR2fXILwBWVGk.png](https://cdn.steemitim...
# 97   ![](https://cdn.steemitimages.com/DQmTBxE7XFtV...
# 96   존 템플턴의 가치 투자 전략 4\n1.\t모두가 부정적인 견해를 보일 때 투자의 기...
# 95   1. 많은 재물보다 명예를 택할 것이요 은이나 금이나 은총을 더욱 택할 것이니라\n...
# ..                                                 ...
# 523  <h1>Steem Kids & Parents</h1>\n<center><h3>Com...
# 522  Dobrý večer s Actifitem. Konečně vypadá počasí...
# 623  <div class="text-justify">\n\n\n![kanchanara-o...
# 622  The human brain controls many of the body's co...
# 621  Greetings folks\n\n![57782C7F-ADC4-4908-A978-2...
#
#                                          json_metadata              created  \
# 99   {"image":["https:\/\/cdn.steemitimages.com\/DQ...  2022-11-08T15:07:24
# 98   {"tags":["nft"],"image":["https:\/\/cdn.steemi...  2022-11-08T15:07:36
# 97   {"tags":["avle-pool","krsuccess","zzan","aaa",...  2022-11-08T15:08:06
# 96   {"tags":["kr","krsuccess"],"app":"steemit\/0.2...  2022-11-08T15:09:24
# 95   {"tags":["hive-138667","bible","krsuccess","kr...  2022-11-08T15:10:03
# ..                                                 ...                  ...
# 523  {"tags":["steemexclusive","technology","steemg...  2022-11-08T19:46:09
# 522  {"community":["hive-193552"],"step_count":["13...  2022-11-08T19:46:15
# 623  {"tags":["crypto","tronfanclub","steemexclusiv...  2022-11-08T19:47:24
# 622  {"tags":["life","brain","humans"],"image":["ht...  2022-11-08T19:47:27
# 621  {"tags":["art","krsuccess","drawing","gems","s...  2022-11-08T19:47:30
#
#              last_update  depth  ...  body_length  \
# 99   2022-11-08T15:10:36      0  ...          388
# 98   2022-11-08T15:07:36      0  ...          125
# 97   2022-11-08T15:08:06      0  ...         5493
# 96   2022-11-08T15:09:24      0  ...          540
# 95   2022-11-08T15:10:03      0  ...         1153
# ..                   ...    ...  ...          ...
# 523  2022-11-08T19:46:09      0  ...        12701
# 522  2022-11-08T19:46:15      0  ...         1439
# 623  2022-11-08T19:47:24      0  ...         5025
# 622  2022-11-08T19:47:27      0  ...         2507
# 621  2022-11-08T19:47:30      0  ...         1467
#
#                                           active_votes author_reputation  \
# 99   [{'voter': 'solidgold', 'rshares': '4135894957...     8446303185839
# 98   [{'voter': 'ididid', 'rshares': '18017296404',...                 0
# 97   [{'voter': 'bert0', 'rshares': '45845794787', ...   187643417195608
# 96   [{'voter': 'upvu', 'rshares': '734061857045', ...     6407176188675
# 95   [{'voter': 'jsquare', 'rshares': '553845098088...    10180703228549
# ..                                                 ...               ...
# 523                                                 []    37153522909717
# 522                                                 []    54394570956352
# 623                                                 []    27331701354422
# 622                                                 []  1085314375681101
# 621                                                 []     9623506263980
#
#     parent_author parent_permlink  \
# 99            NaN     hive-132554
# 98            NaN             nft
# 97            NaN     hive-101145
# 96            NaN              kr
# 95            NaN     hive-138667
# ..            ...             ...
# 523           NaN     hive-139765
# 522           NaN     hive-193552
# 623           NaN     hive-183397
# 622           NaN            life
# 621           NaN             art
#
#                                                    url  \
# 99   /hive-132554/@boss-indo/6qrlf6-alam-sekitar-or...
# 98     /nft/@bishwa/any-body-want-free-nft-legit-onely
# 97                           /hive-101145/@bitai/uf6u9
# 96                                    /kr/@bio92/237-4
# 95                   /hive-138667/@gerizim/ge1la8cmfg3
# ..                                                 ...
# 523  /hive-139765/@morpheussa/quick-stats-steem-kid...
# 522  /hive-193552/@krakonos/actifit-krakonos-202211...
# 623  /hive-183397/@icon-monday/an-anatomy-of-crypto...
# 622  /life/@sarkari/body-or-brain-what-is-it-to-be-...
# 621  /art/@mayorfaruk/smudge-painting-of-a-lady-wit...
#
#                                             root_title  \
# 99                              Alam Sekitar | Klip 42
# 98                  Any body want free nft legit onely
# 97                                         가족 모두 격리 해제
# 96   237.  존 템플의 가치 투자 전략 4 (로렌 템플턴, 스콧 필립스 '존 템플턴의...
# 95                                              잠언 22장
# ..                                                 ...
# 523  Quick Stats - Steem Kids & Parents - Active Po...
# 522            My Actifit Report Card: November 8 2022
# 623                          An Anatomy of crypto coin
# 622            Body Or Brain - What is it to Be Human?
# 621         SMUDGE PAINTING OF A LADY WITH BLONDE HAIR
#
#                                       beneficiaries max_accepted_payout  \
# 99                                               []     1000000.000 SBD
# 98                                               []     1000000.000 SBD
# 97                                               []     1000000.000 SBD
# 96                                               []     1000000.000 SBD
# 95                                               []     1000000.000 SBD
# ..                                              ...                 ...
# 523      [{'account': 'steemkids', 'weight': 1000}]     1000000.000 SBD
# 522     [{'account': 'actifit.pay', 'weight': 500}]     1000000.000 SBD
# 623  [{'account': 'tron-fan-club', 'weight': 1000}]     1000000.000 SBD
# 622                                              []     1000000.000 SBD
# 621                                              []     1000000.000 SBD
#
#      percent_steem_dollars
# 99                   10000
# 98                   10000
# 97                   10000
# 96                   10000
# 95                   10000
# ..                     ...
# 523                  10000
# 522                  10000
# 623                  10000
# 622                  10000
# 621                  10000
#
# [624 rows x 29 columns]

# %%
# dd.sort_values('created')

dd.created.max()
# Out:
# '2022-11-08T18:45:27'

# %%
import json

json.dumps(['post_id', 'author', 'permlink', 'category', 'title', 'body',
       'json_metadata', 'created', 'last_update', 'depth', 'children',
       'net_rshares', 'last_payout', 'cashout_time', 'total_payout_value',
       'curator_payout_value', 'pending_payout_value', 'promoted', 'replies',
       'body_length', 'active_votes', 'author_reputation', 'parent_author',
       'parent_permlink', 'url', 'root_title', 'beneficiaries',
       'max_accepted_payout', 'percent_steem_dollars'])
# Out:
# '["post_id", "author", "permlink", "category", "title", "body", "json_metadata", "created", "last_update", "depth", "children", "net_rshares", "last_payout", "cashout_time", "total_payout_value", "curator_payout_value", "pending_payout_value", "promoted", "replies", "body_length", "active_votes", "author_reputation", "parent_author", "parent_permlink", "url", "root_title", "beneficiaries", "max_accepted_payout", "percent_steem_dollars"]'

# %%
d1[0]['created']
# Out:
# '2022-11-08T04:34:24'

# %%
d2[0]['title']
# Out:
# '2022-11-08T04:34:24'

# %%
list(map(lambda x: x['created'],collected))
# Out:
# ['2022-11-08T04:24:27',
#  '2022-11-08T04:23:57',
#  '2022-11-08T04:23:54',
#  '2022-11-08T04:23:27',
#  '2022-11-08T04:23:15',
#  '2022-11-08T04:23:00',
#  '2022-11-08T04:23:00',
#  '2022-11-08T04:22:15',
#  '2022-11-08T04:22:00',
#  '2022-11-08T04:21:24',
#  '2022-11-08T04:21:03',
#  '2022-11-08T04:20:42',
#  '2022-11-08T04:20:15',
#  '2022-11-08T04:19:51',
#  '2022-11-08T04:19:36',
#  '2022-11-08T04:19:36',
#  '2022-11-08T04:19:30',
#  '2022-11-08T04:19:18',
#  '2022-11-08T04:18:24',
#  '2022-11-08T04:18:15',
#  '2022-11-08T04:18:09',
#  '2022-11-08T04:17:51',
#  '2022-11-08T04:17:36',
#  '2022-11-08T04:17:18',
#  '2022-11-08T04:16:12',
#  '2022-11-08T04:16:03',
#  '2022-11-08T04:15:45',
#  '2022-11-08T04:15:21',
#  '2022-11-08T04:15:00',
#  '2022-11-08T04:14:33',
#  '2022-11-08T04:14:21',
#  '2022-11-08T04:14:12',
#  '2022-11-08T04:14:09',
#  '2022-11-08T04:13:54',
#  '2022-11-08T04:13:30',
#  '2022-11-08T04:12:36',
#  '2022-11-08T04:09:00',
#  '2022-11-08T04:09:00',
#  '2022-11-08T04:08:54',
#  '2022-11-08T04:08:09',
#  '2022-11-08T04:07:00',
#  '2022-11-08T04:06:51',
#  '2022-11-08T04:06:24',
#  '2022-11-08T04:06:18',
#  '2022-11-08T04:05:33',
#  '2022-11-08T04:05:12',
#  '2022-11-08T04:05:12',
#  '2022-11-08T04:05:03',
#  '2022-11-08T04:05:03',
#  '2022-11-08T04:04:24',
#  '2022-11-08T04:04:18',
#  '2022-11-08T04:04:03',
#  '2022-11-08T04:03:54',
#  '2022-11-08T04:03:45',
#  '2022-11-08T04:03:45',
#  '2022-11-08T04:03:45',
#  '2022-11-08T04:03:00',
#  '2022-11-08T04:02:57',
#  '2022-11-08T04:02:54',
#  '2022-11-08T04:02:06',
#  '2022-11-08T04:01:33',
#  '2022-11-08T04:01:30',
#  '2022-11-08T04:01:09',
#  '2022-11-08T04:01:00',
#  '2022-11-08T04:00:54',
#  '2022-11-08T04:00:09',
#  '2022-11-08T04:00:09',
#  '2022-11-08T04:00:03',
#  '2022-11-08T04:00:00',
#  '2022-11-08T03:58:48',
#  '2022-11-08T03:58:18',
#  '2022-11-08T03:58:18',
#  '2022-11-08T03:57:42',
#  '2022-11-08T03:55:12',
#  '2022-11-08T03:54:54',
#  '2022-11-08T03:54:09',
#  '2022-11-08T03:53:21',
#  '2022-11-08T03:52:57',
#  '2022-11-08T03:52:33',
#  '2022-11-08T03:51:54',
#  '2022-11-08T03:51:33',
#  '2022-11-08T03:51:24',
#  '2022-11-08T03:51:24',
#  '2022-11-08T03:50:42',
#  '2022-11-08T03:50:15',
#  '2022-11-08T03:49:54',
#  '2022-11-08T03:49:36',
#  '2022-11-08T03:49:27',
#  '2022-11-08T03:48:51',
#  '2022-11-08T03:48:33',
#  '2022-11-08T03:48:06',
#  '2022-11-08T03:48:03',
#  '2022-11-08T03:47:48',
#  ...]

# %%
import pandas as pd

df = pd.DataFrame([{'a':1,'b':3}])

# df.to_json('test.json','records',mode='a')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-439b12b4ddd7> in <module>
#       3 df = pd.DataFrame([{'a':1,'b':3}])
#       4
# ----> 5 df.to_json('test.json','records',mode='a')
#
# TypeError: to_json() got an unexpected keyword argument 'mode'

# %%
blocks_per_day = 60 * 60 * 24 // 3
cur = blockchain.get_current_block_num()
history = list(blockchain.history(['comment'],cur-60*30 // 3,cur))
# for block in : 
    # print(block['title'],block['body'])
    # break
# Out:
# WARNING:root:Retry in 1s -- RPCErrorRecoverable: error from api.steemit.com (Unable to acquire database lock) in get_ops_in_block
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-26e0d2d409a0> in <module>
#       1 blocks_per_day = 60 * 60 * 24 // 3
#       2 cur = blockchain.get_current_block_num()
# ----> 3 history = list(blockchain.history(['comment'],cur-60*30 // 3,cur))
#       4 # for block in :
#       5     # print(block['title'],block['body'])
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/steem/blockchain.py in stream(self, filter_by, *args, **kwargs)
#     231             filter_by = [filter_by]
#     232
# --> 233         for ops in self.stream_from(*args, **kwargs):
#     234
#     235             # deal with different self.stream_from() outputs
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/steem/blockchain.py in stream_from(self, start_block, end_block, batch_operations, full_blocks, **kwargs)
#      97                     yield self.steem.get_ops_in_block(block_num, False)
#      98                 else:
# ---> 99                     for ops in self.steem.get_ops_in_block(block_num, False):
#     100                         yield ops
#     101
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/steem/steemd.py in get_ops_in_block(self, block_num, virtual_only)
#     405         """ get_ops_in_block """
#     406         return self.call(
# --> 407             'get_ops_in_block', block_num, virtual_only, api='database_api')
#     408
#     409     def get_state(self, path):
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/steembase/http_client.py in call(self, name, *args, **kwargs)
#     239
#     240                 body = HttpClient.json_rpc_body(name, *args, **body_kwargs)
# --> 241                 response = self.request(body=body)
#     242
#     243                 success_codes = tuple(list(response.REDIRECT_STATUSES) + [200])
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     374             response = conn.urlopen(method, url, **kw)
#     375         else:
# --> 376             response = conn.urlopen(method, u.request_uri, **kw)
#     377
#     378         redirect_location = redirect and response.get_redirect_location()
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     708                 body=body,
#     709                 headers=headers,
# --> 710                 chunked=chunked,
#     711             )
#     712
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     447                     # Python 3 (including for exceptions like SystemExit).
#     448                     # Otherwise it looks like a bug in the code.
# --> 449                     six.raise_from(e, None)
#     450         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/data/blockchain-interoperability/blockchain-social-media/blockchain-sns-env/lib64/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     442                 # Python 3
#     443                 try:
# --> 444                     httplib_response = conn.getresponse()
#     445                 except BaseException as e:
#     446                     # Remove the TypeError from the exception chain in
#
# /usr/lib64/python3.6/http/client.py in getresponse(self)
#    1344         try:
#    1345             try:
# -> 1346                 response.begin()
#    1347             except ConnectionError:
#    1348                 self.close()
#
# /usr/lib64/python3.6/http/client.py in begin(self)
#     305         # read until we get a non-100 response
#     306         while True:
# --> 307             version, status, reason = self._read_status()
#     308             if status != CONTINUE:
#     309                 break
#
# /usr/lib64/python3.6/http/client.py in _read_status(self)
#     266
#     267     def _read_status(self):
# --> 268         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     269         if len(line) > _MAXLINE:
#     270             raise LineTooLong("status line")
#
# /usr/lib64/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /usr/lib64/python3.6/ssl.py in recv_into(self, buffer, nbytes, flags)
#     969                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     970                   self.__class__)
# --> 971             return self.read(nbytes, buffer)
#     972         else:
#     973             return socket.recv_into(self, buffer, nbytes, flags)
#
# /usr/lib64/python3.6/ssl.py in read(self, len, buffer)
#     831             raise ValueError("Read on closed or unwrapped SSL socket.")
#     832         try:
# --> 833             return self._sslobj.read(len, buffer)
#     834         except SSLError as x:
#     835             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /usr/lib64/python3.6/ssl.py in read(self, len, buffer)
#     588         """
#     589         if buffer is not None:
# --> 590             v = self._sslobj.read(len, buffer)
#     591         else:
#     592             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
history
# Out:
# []
